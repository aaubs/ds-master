# %% [markdown]
# The following is a simpler version of the geopandas assignment on US shootings near schools. Here the analysis is reduced to things that may be useful for an app. The app is not yet built, but the data and analysis is prepared for it.
# In addition Folium is used to map out things. Folium integrates well with Streamlit and therefore a good thing to practice. Some fancier things are added in folium to present you with some options (e.g. custom tiles, marcer clusters, popups, etc.).

# %%
import geopandas as gpd
import pandas as pd
from folium.plugins import MarkerCluster
import folium

# %%
police = pd.read_csv('https://raw.githubusercontent.com/aaubs/ds-master/main/data/geopandas_data/SPD_Officer_Involved_Shooting__OIS__Data.csv')
gdf_ps = gpd.read_file('https://raw.githubusercontent.com/aaubs/ds-master/main/data/Public_Schools.geojson')
gdf = gpd.read_file('https://raw.githubusercontent.com/aaubs/ds-master/main/data/geopandas_data/Neighborhood_Map_Atlas_Districts.geojson')

# %%
# Convert the police dataframe to a geodataframe
gdf_police = gpd.GeoDataFrame(police, geometry=gpd.points_from_xy(police['Longitude'], police['Latitude']))
gdf_police.crs = "EPSG:4326"

# %%
# Update CRS for all geo dataframes
gdf_police = gdf_police.to_crs("EPSG:4326")
gdf = gdf.to_crs("EPSG:4326")
gdf_ps = gdf_ps.to_crs("EPSG:4326")

# Spatial joins for neighborhoods and schools with police data
joined_police_gdf = gpd.sjoin(gdf_police, gdf, how="left", predicate="within")
joined_police_ps = gdf_police.sjoin_nearest(gdf_ps, how='left')
# Out:
# /opt/miniconda3/envs/streamlit/lib/python3.9/site-packages/geopandas/array.py:364: UserWarning: Geometry is in a geographic CRS. Results from 'sjoin_nearest' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   warnings.warn(

# %% [markdown]
# ## Spatial Distribution of Data

# %%
# Initialize a map centered on Seattle
m = folium.Map(location=[47.6062, -122.3321], zoom_start=11, tiles="CartoDB positron")

# Use the MarkerCluster plugin to cluster the points (optional, when there are many points)
marker_cluster = MarkerCluster().add_to(m)

# Iterate through the joined police data and add a marker for each incident
for _, row in gdf_police.iterrows():
    popup_content = f"""
    Incident Number: {row['Incident Number']}<br>
    Date/Time: {row['Date / Time']}<br>
    Address: {row['Blurred Address']}<br>
    Officer Rank: {row['Rank']}<br>
    Officer Gender: {row['Officer Gender']}<br>
    Subject Gender: {row['Subject Gender']}<br>
    Subject Race: {row['Subject Race']}<br>
    """
    popup = folium.Popup(popup_content, max_width=300)
    folium.Circle(
        location=[row['Latitude'], row['Longitude']],
        radius=15,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.4,
        popup=popup
    ).add_to(marker_cluster)

# to produce a HTML file
# m.save("Spatial_Distribution.html")

#to simply display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb8af4b6c1bf2769bd8e1904021b7928 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb8af4b6c1bf2769bd8e1904021b7928&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb8af4b6c1bf2769bd8e1904021b7928 = L.map(
#                 &quot;map_cb8af4b6c1bf2769bd8e1904021b7928&quot;,
#                 {
#                     center: [47.6062, -122.3321],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ecfe33cc37a99dfaf3400fc91ead771 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cb8af4b6c1bf2769bd8e1904021b7928);
#
#
#             var marker_cluster_c5271e851bba3f721fed0290560f2f9b = L.markerClusterGroup(
#                 {}
#             );
#             map_cb8af4b6c1bf2769bd8e1904021b7928.addLayer(marker_cluster_c5271e851bba3f721fed0290560f2f9b);
#
#
#             var circle_986e201b109f09d4dcd00ab60eab8267 = L.circle(
#                 [47.54381502, -122.2737411],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_c5271e851bba3f721fed0290560f2f9b);
#
#
#         var popup_0d9e44c74d608eadf7ce63c70855b87e = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_9fd1ef23544cb1823e2b022f2dbf3d8e = $(`&lt;div id=&quot;html_9fd1ef23544cb1823e2b022f2dbf3d8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     Incident Number: 20050000118193&lt;br&gt;     Date/Time: 03/21/2005 06:28:00 PM&lt;br&gt;     Address: 65XX BLOCK OF RAINIER AV S&lt;br&gt;     Officer Rank: Officer&lt;br&gt;     Officer Gender: Male&lt;br&gt;     Subject Gender: Male&lt;br&gt;     Subject Race: Asian&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_0d9e44c74d608eadf7ce63c70855b87e.setContent(html_9fd1ef23544cb1823e2b022f2dbf3d8e);
#
#
#
#         circle_986e201b109f09d4dcd00ab60eab8267.bindPopup(popup_0d9e44c74d608eadf7ce63c70855b87e)
#         ;
#
#
#
#
#             var circle_54316fbb22900a045ed6b1da0001e7c5 = L.circle(
#                 [47.54417731, -122.3345125],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_c5271e851bba3f721fed0290560f2f9b);
#
#
#         var popup_25e337dab9cadb14c272aa5f0ddc960e = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_ae1ded337aa42aefebd9cc7be3b83491 = $(`&lt;div id=&quot;html_ae1ded337aa42aefebd9cc7be3b83491&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     Incident Number: 20050000174022&lt;br&gt;     Date/Time: 04/29/2005 03:30:00 AM&lt;br&gt;     Address: 65XX BLOCK OF 1 AV S&lt;br&gt;     Officer Rank: Officer&lt;br&gt;     Officer Gender: Male&lt;br&gt;     Subject Gender: Male&lt;br&gt;     Subject Race: White&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_25e337dab9cadb14c272aa5f0ddc960e.setContent(html_ae1ded337aa42aefebd9cc7be3b83491);
#
#
#
#         circle_54316fbb22900a045ed6b1da0001e7c5.bindPopup(popup_25e337dab9cadb14c272aa5f0ddc960e)
#         ;
#
#
#
#
#             var circle_8da0f3e9366207bfe615d86b3faf95bb = L.circle(
#                 [47.61462023, -122.3357251],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;

# %% [markdown]
# ## Common Neighborhoods for Police-Involved Shootings

# %%
joined_police_gdf.L_HOOD.value_counts()
# Out:
# L_HOOD
# Downtown               35
# Northeast              28
# Rainier Valley         24
# Central Area           14
# Cascade                13
# Northgate              11
# Capitol Hill            9
# Northwest               9
# Queen Anne              7
# West Seattle            6
# Greater Duwamish        5
# Beacon Hill             5
# University District     3
# North Central           2
# Ballard                 1
# Magnolia                1
# Name: count, dtype: int64

# %%
# Subject Race

gdf_police['Subject Race'].value_counts()

# %% [markdown]
# ## Neighborhoods Without Police-Involved Shootings

# %%
no_shooting_neighborhoods = gdf[~gdf.L_HOOD.isin(joined_police_gdf.L_HOOD.unique().tolist())]

m = folium.Map(location=[47.6062, -122.3321], zoom_start=11, tiles="CartoDB positron")
no_shooting_neighborhoods = no_shooting_neighborhoods.to_crs(epsg=4326)
for _, r in no_shooting_neighborhoods.iterrows():
    sim_geo = gpd.GeoSeries(r["geometry"]).simplify(tolerance=0.001)
    geo_j = sim_geo.to_json()
    geo_j = folium.GeoJson(data=geo_j, style_function=lambda x: {"fillColor": "orange"})
    folium.Popup(r["L_HOOD"]).add_to(geo_j)
    geo_j.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff211229f538262027c5069bc63a2576 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff211229f538262027c5069bc63a2576&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff211229f538262027c5069bc63a2576 = L.map(
#                 &quot;map_ff211229f538262027c5069bc63a2576&quot;,
#                 {
#                     center: [47.6062, -122.3321],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_24d90e7ea8cececac636b75205540ede = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ff211229f538262027c5069bc63a2576);
#
#
#         function geo_json_6c34c17c32cff2971e4852dc0b1bda0b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;orange&quot;};
#             }
#         }
#
#         function geo_json_6c34c17c32cff2971e4852dc0b1bda0b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6c34c17c32cff2971e4852dc0b1bda0b = L.geoJson(null, {
#                 onEachFeature: geo_json_6c34c17c32cff2971e4852dc0b1bda0b_onEachFeature,
#
#                 style: geo_json_6c34c17c32cff2971e4852dc0b1bda0b_styler,
#         });
#
#         function geo_json_6c34c17c32cff2971e4852dc0b1bda0b_add (data) {
#             geo_json_6c34c17c32cff2971e4852dc0b1bda0b
#                 .addData(data)
#                 .addTo(map_ff211229f538262027c5069bc63a2576);
#         }
#             geo_json_6c34c17c32cff2971e4852dc0b1bda0b_add({&quot;bbox&quot;: [-122.376896202287, 47.5139929674891, -122.327330001089, 47.5714805380767], &quot;features&quot;: [{&quot;bbox&quot;: [-122.376896202287, 47.5139929674891, -122.327330001089, 47.5714805380767], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.352718508921, 47.5643855150341], [-122.351421436371, 47.5573265755717], [-122.346566427248, 47.5529266568078], [-122.34353808934, 47.5414467666846], [-122.334939388246, 47.5361545787344], [-122.334524314782, 47.5209035432678], [-122.330917561445, 47.5208999102223], [-122.327330001089, 47.5140102557564], [-122.330974480326, 47.5151676716007], [-122.337042084917, 47.5139929674891], [-122.337522306101, 47.5172578759084], [-122.358531401168, 47.5173626644165], [-122.358510167498, 47.515530245045], [-122.36051819, 47.5155291408442], [-122.360540007245, 47.5173618102106], [-122.376896202287, 47.5174892516912], [-122.376156591975, 47.5640749957806], [-122.372677621555, 47.564505141643], [-122.370185807078, 47.5714805380767], [-122.356202359941, 47.5709583286459], [-122.352718508921, 47.5643855150341]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         var popup_052ec73c931a433fef5c074bc9ac9081 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_767c246b11fc52d710c88ab3f00d55b2 = $(`&lt;div id=&quot;html_767c246b11fc52d710c88ab3f00d55b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Delridge&lt;/div&gt;`)[0];
#                 popup_052ec73c931a433fef5c074bc9ac9081.setContent(html_767c246b11fc52d710c88ab3f00d55b2);
#
#
#
#         geo_json_6c34c17c32cff2971e4852dc0b1bda0b.bindPopup(popup_052ec73c931a433fef5c074bc9ac9081)
#         ;
#
#
#
#
#         function geo_json_cfe3bda7795be43a2803db0dfa69a37b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;orange&quot;};
#             }
#         }
#
#         function geo_json_cfe3bda7795be43a2803db0dfa69a37b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_cfe3bda7795be43a2803db0dfa69a37b = L.geoJson(null, {
#                 onEachFeature: geo_json_cfe3bda7795be43a2803db0dfa69a37b_onEachFeature,
#
#                 style: geo_json_cfe3bda7795be43a2803db0dfa69a37b_styler,
#         });
#
#         function geo_json_cfe3bda7795be43a2803db0dfa69a37b_add (data) {
#             geo_json_cfe3bda7795be43a2803db0dfa69a37b
#                 .addData(data)
#                 .addTo(map_ff211229f538262027c5069bc63a2576);
#         }
#             geo_json_cfe3bda7795be43a2803db0dfa69a37b_add({&quot;bbox&quot;: [-122.398290931587, 47.618607714688, -122.358446755154, 47.665050125973], &quot;features&quot;: [{&quot;bbox&quot;: [-122.398290931587, 47.618607714688, -122.358446755154, 47.665050125973], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.397276785874, 47.665050125973], [-122.395000405894, 47.6632530537795], [-122.387722

# %% [markdown]
# ## Schools Near Shooting Locations

# %%
joined_police_ps = gdf_police.sjoin_nearest(gdf_ps, how='left')
school_counts = joined_police_ps.NAME.value_counts()
school_counts
# Out:
# /opt/miniconda3/envs/streamlit/lib/python3.9/site-packages/geopandas/array.py:364: UserWarning: Geometry is in a geographic CRS. Results from 'sjoin_nearest' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   warnings.warn(
# NAME
# The Center School                 24
# Bailey Gatzert                    19
# Aki Kurose                        15
# Bryant                            13
# Lowell                            11
# Sand Point                         9
# TOPS K-8                           8
# Broadview-Thomson K-8              8
# Thurgood Marshall                  6
# Robert Eagle Staff                 6
# Rainier View                       6
# Beacon Hill Int'l                  5
# Queen Anne Gym                     4
# Sacajawea                          4
# Emerson                            4
# Alki                               3
# Leschi                             3
# Roosevelt                          3
# Greenwood                          3
# BRIDGES                            3
# McClure                            2
# Lafayette                          2
# Hawthorne                          2
# Early Learning Center              2
# Kimball - Interim                  2
# Interagency at Columbia School     2
# Washington                         2
# Catharine Blaine K-8               1
# Meany                              1
# Seattle World School               1
# Gatewood                           1
# Cascadia                           1
# Ingraham                           1
# Garfield                           1
# Olympic View                       1
# Dunlap                             1
# John Stanford Int'l                1
# Licton Springs K-8                 1
# Wedgwood                           1
# Maple                              1
# Rainier Beach                      1
# Nova                               1
# Madrona                            1
# Martin Luther King Jr              1
# Name: count, dtype: int64

# %% [markdown]
# ## Type of Schools Near Shootings

# %%
type_counts = joined_police_ps.TYPE.value_counts()
type_counts
# Out:
# TYPE
# Elementary            108
# Middle School          26
# Option High School     24
# Option Elementary      11
# Service School          9
# High School             6
# NonStandard             4
# Name: count, dtype: int64

# %% [markdown]
# ## Schools Without Police-Involved Shootings

# %%
schools_without_shootings = gdf_ps[~gdf_ps.NAME.isin(joined_police_ps.NAME.unique().tolist())]
schools_without_shootings = schools_without_shootings.to_crs(epsg=4326)
m = folium.Map(location=[47.6062, -122.3321], zoom_start=11, tiles="CartoDB positron")

# Create a marker cluster
marker_cluster = MarkerCluster().add_to(m)

# Loop through each school and add it as a circle on the map within the marker cluster
for _, row in schools_without_shootings.iterrows():
    folium.Circle(
        location=[row.geometry.y, row.geometry.x],
        radius=20,  # you can adjust the radius
        color='violet',
        fill=True,
        fill_color='violet',
        fill_opacity=0.6,
        popup=row['SCHOOL']
    ).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff81e989b9dfe5c1cefe4b4006d0fdf9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff81e989b9dfe5c1cefe4b4006d0fdf9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff81e989b9dfe5c1cefe4b4006d0fdf9 = L.map(
#                 &quot;map_ff81e989b9dfe5c1cefe4b4006d0fdf9&quot;,
#                 {
#                     center: [47.6062, -122.3321],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d0f740d608fbb58e05a85756ac9e7ab = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ff81e989b9dfe5c1cefe4b4006d0fdf9);
#
#
#             var marker_cluster_4ee7d040946b1358808bc24c36ccde01 = L.markerClusterGroup(
#                 {}
#             );
#             map_ff81e989b9dfe5c1cefe4b4006d0fdf9.addLayer(marker_cluster_4ee7d040946b1358808bc24c36ccde01);
#
#
#             var circle_0d4b3ee582e4fa92f7caa4ab2d9ad8af = L.circle(
#                 [47.523610901696486, -122.32469058415133],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;violet&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;violet&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_4ee7d040946b1358808bc24c36ccde01);
#
#
#         var popup_f39ec82285185924911dda6c182aa6f5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d44f235d8aae3bb610065f7e94e72317 = $(`&lt;div id=&quot;html_d44f235d8aae3bb610065f7e94e72317&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CONCORD ELEM&lt;/div&gt;`)[0];
#                 popup_f39ec82285185924911dda6c182aa6f5.setContent(html_d44f235d8aae3bb610065f7e94e72317);
#
#
#
#         circle_0d4b3ee582e4fa92f7caa4ab2d9ad8af.bindPopup(popup_f39ec82285185924911dda6c182aa6f5)
#         ;
#
#
#
#
#             var circle_7dabb0bb4f17c181711b22efcdd3208b = L.circle(
#                 [47.70762860831918, -122.29453073327772],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;violet&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;violet&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_4ee7d040946b1358808bc24c36ccde01);
#
#
#         var popup_c6d9af7b652096c82c4ebebc4a8d7637 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_88c01464c860946a0a6c06e132cbdd83 = $(`&lt;div id=&quot;html_88c01464c860946a0a6c06e132cbdd83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NATHAN HALE HIGH SCHOOL&lt;/div&gt;`)[0];
#                 popup_c6d9af7b652096c82c4ebebc4a8d7637.setContent(html_88c01464c860946a0a6c06e132cbdd83);
#
#
#
#         circle_7dabb0bb4f17c181711b22efcdd3208b.bindPopup(popup_c6d9af7b652096c82c4ebebc4a8d7637)
#         ;
#
#
#
#
#             var circle_64393e3b93ae7f8a7625f2ee9f3de2be = L.circle(
#                 [47.723686163285066, -122.30675545410209],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;violet&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;violet&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_4ee7d040946b1358808bc24c36ccde01);
#
#
#         var popup_fd2d3ed1e185a5b122c10a575478723f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});

# %% [markdown]
# ## School with Most Shootings

# %%
joined_police_ps_max = gdf_police.sjoin_nearest(gdf_ps, how='left', max_distance=0.09, distance_col="distances")
max_shooting_school = joined_police_ps_max.groupby(['NAME'])[['distances', 'NAME']].agg({'distances': 'mean', 'NAME': 'count'})
max_shooting_school
# Out:
# /opt/miniconda3/envs/streamlit/lib/python3.9/site-packages/geopandas/array.py:364: UserWarning: Geometry is in a geographic CRS. Results from 'sjoin_nearest' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   warnings.warn(
#                                 distances  NAME
# NAME
# Aki Kurose                       0.002771    15
# Alki                             0.003770     3
# BRIDGES                          0.011776     3
# Bailey Gatzert                   0.015025    19
# Beacon Hill Int'l                0.009482     5
# Broadview-Thomson K-8            0.010852     8
# Bryant                           0.006201    13
# Cascadia                         0.005362     1
# Catharine Blaine K-8             0.004638     1
# Dunlap                           0.007192     1
# Early Learning Center            0.009174     2
# Emerson                          0.009605     2
# Garfield                         0.005439     1
# Gatewood                         0.005581     1
# Greenwood                        0.015843     3
# Hawthorne                        0.001981     2
# Ingraham                         0.007869     1
# Interagency at Columbia School   0.006206     2
# John Stanford Int'l              0.007397     1
# Kimball - Interim                0.009174     2
# Lafayette                        0.002699     2
# Leschi                           0.031491     3
# Licton Springs K-8               0.004045     1
# Lowell                           0.011324    11
# Madrona                          0.010263     1
# Maple                            0.020937     1
# Martin Luther King Jr            0.003788     1
# McClure                          0.008396     2
# Meany                            0.003327     1
# Nova                             0.001522     1
# Olympic View                     0.005887     1
# Queen Anne Gym                   0.009190     4
# Rainier Beach                    0.004079     1
# Rainier View                     0.016751     3
# Robert Eagle Staff               0.008783     6
# Roosevelt                        0.009932     3
# Sacajawea                        0.008194     4
# Sand Point                       0.003214     9
# Seattle World School             0.002237     1
# TOPS K-8                         0.005986     8
# The Center School                0.013730    24
# Thurgood Marshall                0.003244     6
# Washington                       0.003449     2
# Wedgwood                         0.006400     1
