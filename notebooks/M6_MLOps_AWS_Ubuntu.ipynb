# %% [markdown]
# <a href="https://colab.research.google.com/github/aaubs/ds-master/blob/main/notebooks/M6_MLOps_AWS_Ubuntu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This tutorial is designed to help you become familiar with the essential commands and concepts needed to navigate, manage files, and perform basic tasks within the Ubuntu terminal. By the end of this tutorial, you'll have a solid foundation for working with the command line and using it to accomplish various tasks more efficiently.
#
# - **Navigating Directories:** Understand the directory structure in Ubuntu and learn how to navigate through directories using commands like pwd, cd, and ls.

# %%
#pwd (print working directory): Shows the current directory you're in.
# !pwd
# Out:
# /content

# %%
#ls (list): Lists files and directories in the current directory.
# !ls
# Out:
# sample_data

# %%
#cd (change directory): Navigates to a different directory.
# !cd sample_data/

# %% [markdown]
# - **Creating and Managing Files and Directories:** Learn how to create, copy, move, and delete files and directories using commands such as touch, mkdir, cp, mv, rm, and rmdir.

# %%
#mkdir (make directory): Creates a new directory.
# !mkdir python_aws

# %%
# !ls
# Out:
# python_aws  sample_data

# %%
#touch (create file): Creates a new, empty file.
# !touch python_aws/new_file.txt

# %%
# !cd python_aws && ls
# Out:
# new_file.txt

# %% [markdown]
# - **File Permissions and Ownership:** Discover how to view and modify file permissions and ownership using chmod, chown, and chgrp.

# %%
#cp (copy): Copies a file or directory.
# !cp new_file.txt destination_file.txt

# %%
#mv (move): Moves a file or directory.
# !mv destination_file.txt python_aws/

# %%
#rm (remove): Deletes a file.
# !rm python_aws/new_file.txt

# %%
#rmdir (remove directory): Deletes an empty directory.
# !rm -r python_aws

# %% [markdown]
# - **Text Editing:** Get introduced to text editors such as nano, vim, and cat, and learn how to create, edit, and view the contents of text files.

# %%
# !touch new_file.txt

# %%
# sudo apt-get update
# sudo apt-get install vim

# %%
#vim (text editor)
# !vim new_file.txt
# Out:
# 7[>4;2m="new_file.txt" 0L, 0C▽  [>c~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               0,0-1All>[>4;m8Vim: Caught deadly signal TERM
# Vim: Finished.
#
# ^C

# %%
#cat (concatenate): Displays the contents of a file.
# !cat new_file.txt

# %% [markdown]
# - **Searching and Filtering:** Explore how to search for specific content within files and directories using commands like grep and find.

# %%
# !grep (global regular expression print): Searches for a specific pattern in a file or multiple files.
# !grep 'search_pattern' new_file.txt
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `global'
# /bin/bash: -c: line 0: `grep (global regular expression print): Searches for a specific pattern in a file or multiple files.'

# %%
# !mkdir python_aws

# %%
# !mv new_file.txt python_aws/

# %%
#find (find files): Searches for files and directories in a directory hierarchy based on different criteria.
# !find python_aws/ -iname 'new_file.txt'
# Out:
# python_aws/new_file.txt

# %% [markdown]
# - **Basic System Information and Management:** Learn about commands that help you monitor system resources, manage processes, and perform simple system updates and maintenance.

# %%
# !top
# Out:
# =top - 18:38:14 up 28 min,  0 users,  load average: 0.15, 0.18, 0.23
# Tasks:  15 total,   1 running,  13 sleeping,   0 stopped,   1 zombie
# %Cpu(s):  3.3 us,  0.0 sy,  0.0 ni, 96.7 id,  0.0 wa,  0.0 hi,  0.0 si,  0.0 st
# MiB Mem :  12985.5 total,   9044.0 free,    692.1 used,   3249.4 buff/cache
# MiB Swap:      0.0 total,      0.0 free,      0.0 used.  12012.4 avail Mem
#
#     PID USER      PR  NI    VIRT    RES    SHR S  %CPU  %MEM     TIME+ COMMAND
#     270 root      20   0 1283240 186508  60272 S   6.7   1.4   0:14.01 python3
#       1 root      20   0    1012      8      0 S   0.0   0.0   0:00.65 docker-+
#       6 root      20   0  897648  50948  30848 S   0.0   0.4   0:06.94 node
#      18 root      20   0    5524    512    444 S   0.0   0.0   0:00.73 tail
#      28 root      20   0    6904   3236   2948 S   0.0   0.0   0:01.08 oom_mon+
#      30 root      20   0    6904   1624   1352 S   0.0   0.0   0:00.00 run.sh
#      32 root      20   0  722040  13860   8028 S   0.0   0.1   0:00.99 kernel_+
#      58 root      20   0       0      0      0 Z   0.0   0.0   0:07.22 python3
#      59 root      20   0   73832  40724  13036 S   0.0   0.3   0:00.66 colab-f+
#      80 root      20   0  556536 152912  48692 S   0.0   1.1   0:07.91 jupyter+
#      81 root      20   0  713148   8544   2864 S   0.0   0.1   0:01.00 dap_mul+
#     303 root      20   0  537860  14468   5596 S   0.0   0.1   0:01.72 python3
#     334 root      20   0  888792 122160  30252 S   0.0   0.9   0:14.97 node
#    7247 root      20   0    5488    584    516 S   0.0   0.0   0:00.00 sleep
#    7248 root      20   0    9128   3652   3156 R   0.0   0.0   0:00.01 top
# top - 18:38:17 up 28 min,  0 users,  load average: 0.15, 0.18, 0.23
#
# %Cpu(s):  2.5 us,  1.5 sy,  0.0 ni, 95.8 id,  0.0 wa,  0.0 hi,  0.2 si,  0.0 st
# MiB Mem :  12985.5 total,   9042.5 free,    693.5 used,   3249.5 buff/cache
# MiB Swap:      0.0 total,      0.0 free,      0.0 used.  12010.9 avail Mem
#
#
#       6 root      20   0  897648  51212  30848 S   1.0   0.4   0:06.97 node
#     270 root      20   0 1283240 186508  60272 S   0.7   1.4   0:14.03 python3
#      28 root      20   0    6904   3236   2948 S   0.3   0.0   0:01.09 oom_mon+
#      32 root      20   0  722040  13860   8028 S   0.3   0.1   0:01.00 kernel_+
#      80 root      20   0  556536 152912  48692 S   0.3   1.1   0:07.92 jupyter+
#      81 root      20   0  713148   8544   2864 S   0.3   0.1   0:01.01 dap_mul+
#     303 root      20   0  537860  14468   5596 S   0.3   0.1   0:01.73 python3
#       1 root      20   0    1012      8      0 S   0.0   0.0   0:00.65 docker-+
#      18 root      20   0    5524    512    444 S   0.0   0.0   0:00.73 tail
#      30 root      20   0    6904   1624   1352 S   0.0   0.0   0:00.00 run.sh
#      58 root      20   0       0      0      0 Z   0.0   0.0   0:07.22 python3
#      59 root      20   0   73832  40724  13036 S   0.0   0.3   0:00.66 colab-f+
#
#    7248 root      20   0    9128   3652   3156 R   0.0   0.0   0:00.01 top
#    7262 root      20   0    5488    576    512 S   0.0   0.0   0:00.00 sleep
# top - 18:38:20 up 28 min,  0 users,  load average: 0.14, 0.18, 0.23
#
# %Cpu(s):  8.4 us,  3.7 sy,  0.0 ni, 87.6 id,  0.2 wa,  0.0 hi,  0.2 si,  0.0 st
# MiB Mem :  12985.5 total,   9041.3 free,    694.6 used,   3249.6 buff/cache
# MiB Swap:      0.0 total,      0.0 free,      0.0 used.  12009.8 avail Mem
#
#
#     270 root      20   0 1283240 186508  60272 S   1.3   1.4   0:14.07 python3
#       6 root      20   0  897648  51476  30848 S   0.3   0.4   0:06.98 node
#      80 root      20   0  556536 152912  48692 S   0.3   1.1   0:07.93 jupyter+
#      81 root      20   0  713148   8544   2864 S   0.3   0.1   0:01.02 dap_mul+
#     303 root      20   0  537860  14468   5596 S   0.3   0.1   0:01.74 python3
#       1 root      20   0    1012      8      0 S   0.0   0.0   0:00.65 docker-+
#      18 root      20   0    5524    512    444 S   0.0   0.0   0:00.73 tail
#      28 root      20   0    6904   3236   2948 S   0.0   0.0   0:01.09 oom_mon+
#      30 root      20   0    6904   1624   1352 S   0.0   0.0   0:00.00 run.sh
#      32 root      20   0  722040  13860   8028 S   0.0   0.1   0:01.00 kernel_+
#
#
#
#
#    7274 root      20   0    5488    520    448 S   0.0   0.0   0:00.00 sleep
# >

# %%
#chmod (change mode): Changes the permissions of a file or directory.
# !chmod 755 python_aws/new_file.txt

# %%
#Use the nproc command to find the number of CPU cores on your system.
# !nproc
# Out:
# 2

# %% [markdown]
# <img src="https://raw.githubusercontent.com/aaubs/ds-master/main/data/Images/Exercise.png" width="600">

# %% [markdown]
# ####Exercise 1: Create a directory structure and manage files
#
# - Create a new directory called exercise1 in your home directory.
# Navigate to the exercise1 directory.
# - Create three subdirectories: images, documents, and scripts.
# - Navigate to the images directory and create two empty image files: image1.jpg and image2.png.
# - Copy image1.jpg to the documents directory and rename it to image1_copy.jpg.
# - Move image2.png to the scripts directory.
# - List the contents of the exercise1 directory and its subdirectories to verify your actions.
