# %% [markdown]
# # M1 group assignment — starter
#
# **Group:** _number_ · **Members:** _names_ · **Video:** _link_
#
# Replace the line above before you submit. The full brief, including how this is
# marked, is in [assignment.md](../courses/ds4b-m1-3-pandas-2026/assignment.md).
#
# This starter gives you the data loading and the section headings. Everything else is
# yours to write. Delete any prompt comment once you have answered it.
#
# **Before you submit: Restart & Run All.** If it does not run top to bottom from a fresh
# kernel, it is not finished.

# %%
# Setup. This cell is given to you; you should not need to change it.
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

print(f"pandas {pd.__version__}")
print(f"numpy {np.__version__}")

CLASS_DATA_URL = "https://raw.githubusercontent.com/aaubs/ds-master/codex/m1-pandas-2026/data/M1_2026"


def load_class_csv(filename):
    """Read a class data file: the local copy if there is one, otherwise the class URL."""
    candidates = [Path("data/M1_2026") / filename,
                  Path("../data/M1_2026") / filename,
                  Path("ds-master/data/M1_2026") / filename,
                  Path("../ds-master/data/M1_2026") / filename]
    for path in candidates:
        if path.exists():
            print(f"Loaded {filename} from {path}")
            return pd.read_csv(path)
    url = f"{CLASS_DATA_URL}/{filename}"
    print(f"Loaded {filename} from {url}")
    return pd.read_csv(url)


songs_raw = load_class_csv("spotify_songs.csv")
families_raw = load_class_csv("subgenre_families.csv")

print(f"songs_raw:    {songs_raw.shape[0]:,} rows x {songs_raw.shape[1]} columns")
print(f"families_raw: {families_raw.shape[0]:,} rows x {families_raw.shape[1]} columns")

# %% [markdown]
# ## 1 · What is one row?
#
# State what one row of `songs_raw` represents, and show the output that convinced you.
# Then decide the grain of the working table you will build, and say why it fits Part A.

# %%
# Your evidence for the row meaning of songs_raw.

# %%
# Build your working table here, and show that its grain is what you claim.

# %% [markdown]
# ## 2 · Audit before deciding
#
# Missingness in the fields your answer depends on, and what you decided for each —
# including the fields where the decision is to leave them alone. Then release dates:
# what precision is actually recorded, and what parsing would invent.

# %%
# Missingness audit.

# %%
# Release-date precision.

# %% [markdown]
# ## 3 · Reach: how many playlists is each track on?
#
# Two reasonable-looking ways to compute this disagree on this dataset. Show which one
# you are reporting and the check that settled it.

# %%
# Reach per track, plus the check.

# %% [markdown]
# ## 4 · Join the family lookup
#
# Predict the row count first, in a comment or a printed number. Then merge with
# `validate=` and `indicator=`, and compare with your prediction.
#
# If it does not behave as you predicted: diagnose the keys, decide what to do, and
# record what the decision costs. Report how many rows end up unlabelled.

# %%
# Predicted rows after the join:

# %%
# The merge, with validation and an indicator.

# %%
# Diagnose the keys.

# %%
# Your fix, and what it costs.

# %% [markdown]
# ## 5 · Parts A and B
#
# A summary table with counts next to every mean, then the same answer at three or more
# cut-offs for "travelling". For Part B, say which families are too small to carry it.

# %%
# Part A: travelling versus not.

# %%
# Cut-off sensitivity.

# %%
# Part B: within family.

# %% [markdown]
# ## 6 · One chart, and what it means
#
# Reshape as needed, draw one chart that carries your claim, then write 250–400 words:
# what you found, what it rests on, and at least two things this data cannot tell the
# curation team. Part C — your own question — goes here too.

# %%
# Reshape for the chart.

# %%
# The chart.

# %% [markdown]
# ### Interpretation
#
# _250–400 words._
#
# ### Part C · Our own question
#
# _State the question, answer it, and give it one limitation._

# %% [markdown]
# ## Decision log
#
# One line each. What you decided, and what it cost you.
#
# | Task | Decision | What it cost |
# |---|---|---|
# | 1 · Grain | | |
# | 2 · Audit | | |
# | 3 · Reach | | |
# | 4 · Join | | |
#
# ## Where we used AI assistance
#
# _A few lines: which tool, for what. See the brief — the condition is that you can
# explain every line you submit._
#
# ## Before submitting
#
# - [ ] First cell has group, names and a video link that works for someone outside the group
# - [ ] Restart & Run All, from a fresh kernel, produces this notebook
# - [ ] Sections 1–6 present and in order, prompt comments removed
# - [ ] Decision log filled in
# - [ ] Every member speaks in the video, each on a different decision
