# %% [markdown]
# # M1 group assignment — starter
#
# **Group:** _number_ · **Members:** _names_ · **Video:** _link_
#
# Replace the line above before you submit. The three questions, and how they are marked,
# are in [assignment.md](../courses/ds4b-m1-3-pandas-2026/assignment.md).
#
# This starter gives you the data loading and the headings. Everything else is yours to
# write. Delete each prompt comment once you have answered it.
#
# **Before you submit: Restart & Run All.** If it does not run top to bottom from a fresh
# kernel, it is not finished.

# %%
# Setup. This cell is given to you; you should not need to change it.
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

print(f"pandas {pd.__version__}")
print(f"numpy {np.__version__}")

CLASS_DATA_URL = "https://raw.githubusercontent.com/aaubs/ds-master/codex/m1-pandas-2026/data/M1_2026"


def load_class_csv(filename):
    """Read a class data file: the local copy if there is one, otherwise the class URL."""
    candidates = [Path("data/M1_2026") / filename,
                  Path("../data/M1_2026") / filename,
                  Path("ds-master/data/M1_2026") / filename,
                  Path("../ds-master/data/M1_2026") / filename]
    for path in candidates:
        if path.exists():
            print(f"Loaded {filename} from {path}")
            return pd.read_csv(path)
    url = f"{CLASS_DATA_URL}/{filename}"
    print(f"Loaded {filename} from {url}")
    return pd.read_csv(url)


songs_raw = load_class_csv("spotify_songs.csv")
families_raw = load_class_csv("subgenre_families.csv")

print(f"songs_raw:    {songs_raw.shape[0]:,} rows x {songs_raw.shape[1]} columns")
print(f"families_raw: {families_raw.shape[0]:,} rows x {families_raw.shape[1]} columns")

# %% [markdown]
# ## Question 1 · What is one row, and how far does each track travel?

# %%
# What one row of songs_raw represents — with the output that convinced you.

# %%
# Your working table. Show that its grain is what you claim it is.

# %%
# Reach per track, and the check that settled which computation you trust.

# %%
# Audit of the fields your answer depends on: missingness, and date precision.

# %% [markdown]
# ## Question 2 · Attach the family label
#
# Write your predicted row count down before you merge.

# %%
# Predicted rows after the merge:

# %%
# The merge, with validate= and indicator=.

# %%
# Diagnose the keys.

# %%
# Your decisions, and what each one costs.

# %% [markdown]
# ## Question 3 · Do travelling tracks differ?

# %%
# Travelling versus not, with counts next to every mean.

# %%
# Three or more cut-offs.

# %%
# Within family. Which families are too small to carry it?

# %%
# Reshape, then one chart.

# %% [markdown]
# ### Interpretation
#
# _250–400 words: what you found, what it rests on, and at least two things this data
# cannot tell the curation team._
#
# ## Decision log
#
# One line per question. What you decided, and what it cost you.
#
# | Question | Decision | What it cost |
# |---|---|---|
# | 1 · Grain and reach | | |
# | 2 · The join | | |
# | 3 · Cut-off and comparison | | |
#
# ## Where we used AI assistance
#
# _A few lines: which tool, for what. The condition is that you can explain every line you
# submit — you are about to present it._
#
# ## Before submitting
#
# - [ ] First cell has group, names and a video link that works for someone outside the group
# - [ ] Restart & Run All, from a fresh kernel, produces this notebook
# - [ ] All three questions present and in order, prompt comments removed
# - [ ] Decision log filled in
# - [ ] Every member speaks in the video, each on a different decision
