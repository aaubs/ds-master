# %% [markdown]
# <a href="https://colab.research.google.com/github/aaubs/ds-master/blob/main/notebooks/Extra_Exercises_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Extra exercise for EDA

# %% [markdown]
# # Project Title - Disney Catalogue Analysis
# ## About the Dataset
# These dataset contains 8807 movies and tv shoes and their case .
# Try to write your own functions and know your keyboard shortcuts. This is very similar to the other exercise but it will train you to write out the code and you can challenge yourself by making cool graphs to go with this datasets.

# %% [markdown]
# ![](https://aaubs.github.io/ds-master/media/M1-extra-EDA-ass-img1.png)

# %% [markdown]
# # Part 1

# %% [markdown]
# ## Goals of Part 1
#     # 1. reading csv file
#     # 2. understanding the data
# ## Relevant functions for this Part
#     # 1. pd.read_csv()
#     # 2. df.head()
#     # 3. df.shape
#     # 4. df.columns
#     # 5. df.index
#     # 6. df.describe() or df.info()
#     # 7. df['column_name'].unique()
#     # 7.1 df['column_name'].nunique()
#     # 8. df['column_name'].value_counts()
#     # 9. df['column_name'].sum() [count(), min(), max(), std(), etc.]

# %% [markdown]
# ## Exercises Part 1

# %%
# Step 1. Import the necessary libraries

# %%
# Step 2. Import the dataset from this address.
# link to data: 'https://raw.githubusercontent.com/aaubs/ds-master/main/data/disney_plus_titles.csv'
# Extra challenge: try downloading it from Kaggle in your Google drive and open it from there
# link to kaggle: https://www.kaggle.com/datasets/shivamb/disney-movies-and-tv-shows

# %%
# Step 3. See the first 10 entries
# Out:
#   show_id   type                                             title  \
# 0      s1  Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2  Movie                            Ernest Saves Christmas
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
#
#                                                 cast country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...     NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale     NaN
#
#           date_added  release_year rating duration          listed_in  \
# 0  November 26, 2021          2016   TV-G   23 min  Animation, Family
# 1  November 26, 2021          1988     PG   91 min             Comedy
#
#                                          description
# 0   Join Mickey and the gang as they duck the halls!
# 1  Santa Claus passes his magic bag to a new St. ...

# %%
# Step 4. What is the number of observations in the dataset?
# and What is the number of columns in the dataset?
# Solution 1
# Out:
# (1450, 12)

# %%
# Solution 2
# Out:
# <bound method DataFrame.info of      show_id     type                                             title  \
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2    Movie                            Ernest Saves Christmas
# 2         s3    Movie                      Ice Age: A Mammoth Christmas
# 3         s4    Movie                        The Queen Family Singalong
# 4         s5  TV Show                             The Beatles: Get Back
# ...      ...      ...                                               ...
# 1445   s1446    Movie                          X-Men Origins: Wolverine
# 1446   s1447    Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448    Movie                                   Eddie the Eagle
# 1448   s1449    Movie                              Bend It Like Beckham
# 1449   s1450    Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# ...

# %%
# Step 5. Print the name of all the columns.
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# Step 6. How is the dataset indexed?
# Out:
# RangeIndex(start=0, stop=1450, step=1)

# %%
# Step 7a. Print a descriptive summary of a DataFrame
# Out:
#        release_year
# count   1450.000000
# mean    2003.091724
# std       21.860162
# min     1928.000000
# 25%     1999.000000
# 50%     2011.000000
# 75%     2018.000000
# max     2021.000000

# %%
# Step 7b. Print columns that contain quantitative data
# Out:
#    release_year
# 0          2016
# 1          1988
# 2          2011
# 3          2021
# 4          2021

# %%
# Step 8. What kind of types of media  are offered in this dataset?
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
# Step 9. Are there more movies or TV shows on Disney+
# Out:
# Movie      1052
# TV Show     398
# Name: type, dtype: int64

# %%
# Step 10. How many ratings exists in the dataset ?
# Out:
# array(['TV-G', 'PG', 'TV-PG', nan, 'PG-13', 'TV-14', 'G', 'TV-Y7', 'TV-Y',
#        'TV-Y7-FV'], dtype=object)

# %%
# Step 101. How many movies are in each rating category?
# Out:
# TV-G        318
# TV-PG       301
# G           253
# PG          236
# TV-Y7       131
# TV-14        79
# PG-13        66
# TV-Y         50
# TV-Y7-FV     13
# Name: rating, dtype: int64

# %%
# Step 11a. What is the newest movie available?
#print its release year
# Out:
# 2021

# %%
# Step 11a. What is the oldest movie available?
#print its release year
# Out:
# 1928

# %%
# Step 12. Find the number of directors that there are
    # 1. calculate the revenue for each course
    # 2. sum all
# Out:
# 609

# %%
# Out:
# 0       Alonso Ramirez Ramos, Dave Wasson
# 1                             John Cherry
# 2                            Karen Disher
# 3                         Hamish Hamilton
# 4                                     NaN
#                       ...
# 1445                           Gavin Hood
# 1446                           Shawn Levy
# 1447                      Dexter Fletcher
# 1448                      Gurinder Chadha
# 1449                          Mark Waring
# Name: director, Length: 1450, dtype: object

# %% [markdown]
# # Part 2

# %% [markdown]
# ## Goals of Part 2
#     # 1. Accessing and filtering
#
# ## Relevant functions for this Part
#     # 1. Boolean Masking [[]]
#     # 2. df.sum()
#     # 3. df.unique()
#     # 4. df['column_name'].nlargest()
#     # 5. df['column_name'].sort_values()
#     # 6. df['column_name'].value_counts()

# %% [markdown]
# ![](https://aaubs.github.io/ds-master/media/M1-extra-EDA-ass-img2.png)

# %% [markdown]
# ## Exercises Part 2

# %%
# Step 14. Divide the TV shows from the movies

# %%
# Step 14a. Show the 10 oldest movies
# Out:
#                          title  release_year rating   type
# 1220          Steamboat Willie          1928  TV-Y7  Movie
# 736         Babes in the Woods          1932  TV-Y7  Movie
# 1178          Santa's Workshop          1932   TV-G  Movie
# 893          Flowers and Trees          1932  TV-Y7  Movie
# 1317            The Pied Piper          1933   TV-G  Movie
# 1418             Ye Olden Days          1933  TV-Y7  Movie
# 1362         Three Little Pigs          1933  TV-Y7  Movie
# 922   Grasshopper and the Ants          1934   TV-G  Movie
# 1356       The Wise Little Hen          1934   TV-G  Movie
# 1279     The Goddess of Spring          1934  TV-Y7  Movie

# %%
# Step 14b. Show the 10 oldest shows
# Out:
#                                        title  release_year    rating     type
# 1071             Mickey Mouse Club (1955-59)          1955     TV-PG  TV Show
# 1244        The Adventures of Spin and Marty          1955      TV-G  TV Show
# 221                        Schoolhouse Rock!          1973      TV-G  TV Show
# 299                          The Muppet Show          1976     TV-PG  TV Show
# 1207                            Spider-Woman          1979     TV-Y7  TV Show
# 1205      Spider-Man and His Amazing Friends          1982     TV-Y7  TV Show
# 195                Star Wars Vintage: Droids          1985  TV-Y7-FV  TV Show
# 841   Disney's Adventures Of The Gummi Bears          1985     TV-Y7  TV Show
# 267                         Star Wars: Ewoks          1985  TV-Y7-FV  TV Show
# 1312   The New Adventures of Winnie the Pooh          1988      TV-Y  TV Show

# %%
# Step 15. How many movies were released in 2020
# Out:
# 74

# %%
# Step 16. Show all movies by Shawn Levy where the year is below 2009
# Out:
#     show_id   type                 title    director  \
# 262    s263  Movie   Night at the Museum  Shawn Levy
# 295    s296  Movie  Cheaper By the Dozen  Shawn Levy
#
#                                                   cast  \
# 262  Ben Stiller, Carla Gugino, Dick Van Dyke, Mick...
# 295  Steve Martin, Bonnie Hunt, Hilary Duff, Tom We...
#
#                            country         date_added  release_year rating  \
# 262  United States, United Kingdom      April 2, 2021          2006     PG
# 295                  United States  February 19, 2021          2003     PG
#
#     duration                         listed_in  \
# 262  109 min  Action-Adventure, Comedy, Family
# 295   99 min                    Comedy, Family
#
#                                            description
# 262  A new guard at the Natural History Museum find...
# 295  Tom and Kate Baker discover that managing twel...

# %%
#Step 17. Show all movies that have a PG rating after the year 2006
# Out:
#      show_id   type                                           title  \
# 19       s20  Movie                                       Enchanted
# 23       s24  Movie                           Home Sweet Home Alone
# 44       s45  Movie                            Jingle All the Way 2
# 55       s56  Movie                                  McFarland, USA
# 80       s81  Movie                         Alvin and the Chipmunks
# ...      ...    ...                                             ...
# 1416   s1417  Movie                                  Wreck-It Ralph
# 1428   s1429  Movie                                        Zootopia
# 1442   s1443  Movie                                    Tomorrowland
# 1444   s1445  Movie                  Ice Age: Dawn Of The Dinosaurs
# 1446   s1447  Movie  Night at the Museum: Battle of the Smithsonian
#
#                       director  \
# 19                  Kevin Lima
# 23                   Dan Mazer
# 44                   Alex Zamm
# ...

# %%
# Step 21. How many different movies are there?
# Sloution 1
# Out:
# 117

# %% [markdown]
# # Part 3

# %% [markdown]
# ## Goals of Part 3
#     # 1. Slicing
#          - loc
#          - iloc
#     # 2. Missing value
#          - Detecting
#          - Dropping
#          - Filling
#     # 3. Combining two datasets
#          - Merge
#
#
# ## Relevant functions for this Part
#     # 1. df.iloc() & df.loc()
#     # 2. df.isnull() & df.notnull()
#     # 3. df.dropna()
#     # 4. df.fillna()
#     # 5. df.merge()
#     # 6. df.concat()

# %% [markdown]
# ![](https://aaubs.github.io/ds-master/media/M1-extra-EDA-ass-img3.png)

# %%
# Step 22. Import the dataset from this address.
# link to data: 'https://raw.githubusercontent.com/aaubs/ds-master/main/data/amazon_prime_titles.csv' & 'https://raw.githubusercontent.com/aaubs/ds-master/main/data/netflix_titles.csv'
# Extra challenge: try downloading it from Kaggle in your Google drive and open it from there
# link to kaggle: https://www.kaggle.com/datasets/shivamb/amazon-prime-movies-and-tv-shows & https://www.kaggle.com/datasets/shivamb/netflix-shows

# %%
# Step 23. Inspect the new datasets, first lines and the shape
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
# Out:
#   show_id   type                 title      director  \
# 0      s1  Movie   The Grand Seduction  Don McKellar
# 1      s2  Movie  Take Care Good Night  Girish Joshi
#
#                                                cast country      date_added  \
# 0    Brendan Gleeson, Taylor Kitsch, Gordon Pinsent  Canada  March 30, 2021
# 1  Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar   India  March 30, 2021
#
#    release_year rating duration             listed_in  \
# 0          2014    NaN  113 min         Comedy, Drama
# 1          2018    13+  110 min  Drama, International
#
#                                          description
# 0  A small fishing village must procure a local d...
# 1  A Metro Family decides to fight a Cyber Crimin...

# %%
# Out:
# The shape of netflix dataset :  (8807, 12)
# The shape of amazon dataset :  (9668, 12)
# The shape of disney dataset :  (1450, 12)

# %%
# Step 24. Concatenante the datasets and create an extra column to say from which platform the values are from

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19925 entries, 0 to 19924
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       19925 non-null  object
#  1   type          19925 non-null  object
#  2   title         19925 non-null  object
#  3   director      14736 non-null  object
#  4   cast          17677 non-null  object
#  5   country       9879 non-null   object
#  6   date_added    10399 non-null  object
#  7   release_year  19925 non-null  int64
#  8   rating        19581 non-null  object
#  9   duration      19922 non-null  object
#  10  listed_in     19925 non-null  object
#  11  description   19925 non-null  object
#  12  platform      19925 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 2.0+ MB

# %%
# Step 25 Check for duplicates
# Out:
# 0

# %%
#Step 26. Check the country that have empty values and remplace it with the mode.
# Out:
# False    19925
# Name: country, dtype: int64

# %%
#Step 27. Check the missing values in the director columns and replace them with "Unknown"

# %%
#Step 28. Do the same for the cast

# %%
#Step 29. Drop all missing values.

# %% [markdown]
# ![](https://aaubs.github.io/ds-master/media/M1-extra-EDA-ass-img4.png)
