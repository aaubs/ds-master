# %% [markdown]
# <a href="https://colab.research.google.com/github/aaubs/ds-master/blob/main/notebooks/M1-Linear-Algebra-Vectors-V5-Exercises-Solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title import
import math
import numpy as np
import matplotlib.pyplot as plt
# !wget https://raw.githubusercontent.com/HamidBekamiri/Linear-Algebra/main/CarPrice_Assignment.csv
# Out:
# --2022-09-20 09:49:50--  https://raw.githubusercontent.com/HamidBekamiri/Linear-Algebra/main/CarPrice_Assignment.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26717 (26K) [text/plain]
# Saving to: ‘CarPrice_Assignment.csv’
#
# CarPrice_Assignment 100%[===================>]  26.09K  --.-KB/s    in 0.002s
#
# 2022-09-20 09:49:50 (10.5 MB/s) - ‘CarPrice_Assignment.csv’ saved [26717/26717]

# %%
#@title install handcalcs

# !pip install handcalcs -q
# !pip install innerscope -q
import handcalcs.render
from math import sqrt, pi
from handcalcs.decorator import handcalc
from math import sqrt
# Out:
#      |████████████████████████████████| 89 kB 2.9 MB/s
#      |████████████████████████████████| 271 kB 24.9 MB/s
#      |████████████████████████████████| 71 kB 168 kB/s
#      |████████████████████████████████| 133 kB 55.8 MB/s
#      |████████████████████████████████| 107 kB 57.6 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# flask 1.1.4 requires Jinja2<3.0,>=2.10.1, but you have jinja2 3.1.2 which is incompatible.

# %%
#@title Figure settings
import ipywidgets as widgets       # interactive display
from ipywidgets import fixed
# %config InlineBackend.figure_format = 'retina'
plt.style.use("https://raw.githubusercontent.com/NeuromatchAcademy/course-content/master/nma.mplstyle")
# %matplotlib inline
from matplotlib import pyplot
from urllib.request import urlretrieve
URL = 'https://go.gwu.edu/engcomp4plot'
urlretrieve(URL, 'plot_helper.py')
import sys
sys.path.append('../scripts/')
from plot_helper import *
# !wget "https://raw.githubusercontent.com/HamidBekamiri/Linear-Algebra/main/CarPrice_Assignment.csv?token=GHSAT0AAAAAABUHW5ANNAFZJBTAAMDDYHZAYTXMASA"

# %%
# @title Plotting functions
def visualize_vectors(v, v_unit):
  """ Plots a 2D vector and the corresponding unit vector

  Args:
    v (ndarray): array of size (2,) with the vector coordinates
    v_unit (ndarray): array of size (2, ) with the unit vector coordinates

  """
  fig, ax = plt.subplots()

  # Set up plot aesthetics
  ax.spines['top'].set_color('none')
  ax.spines['bottom'].set_position('zero')
  ax.spines['left'].set_position('zero')
  ax.spines['right'].set_color('none')
  ax.set(xlim = [-6, 6], ylim = [-6, 6])
  ax.grid(True, alpha=.4, linewidth=1, zorder=0)

  # Plot vectors
  v_arr = ax.arrow(0, 0, v[0], v[1], width=0.08, color='#648FFF', length_includes_head = True, zorder = 2);
  v_unit_arr = ax.arrow(0, 0, v_unit[0], v_unit[1], width=0.08, color='#DC267F', length_includes_head = True, zorder = 3);
  ax.set(xlim = [-4, 4], ylim = [-4, 4]);

  # Add legend
  leg = ax.legend([v_arr, v_unit_arr], [r"Vector $\mathbf{v}$", r"Normalized vector $\tilde{\mathbf{v}}$"], handlelength = 0, fontsize = 20, loc = 'upper left')
  for handle, label in zip(leg.legendHandles, leg.texts):
    label.set_color(handle.get_facecolor())
    handle.set_visible(False)

from matplotlib.patches import FancyArrowPatch
from mpl_toolkits.mplot3d import proj3d

class Arrow3D(FancyArrowPatch):
    def __init__(self, xs, ys, zs, *args, **kwargs):
        FancyArrowPatch.__init__(self, (0,0), (0,0), *args, **kwargs)
        self._verts3d = xs, ys, zs

    def draw(self, renderer):
        xs3d, ys3d, zs3d = self._verts3d
        xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
        self.set_positions((xs[0],ys[0]),(xs[1],ys[1]))
        FancyArrowPatch.draw(self, renderer)

# %% [markdown]
# # Section 1: What is a vector?

# %% [markdown]
# ## Assignment 1
# Define and Plot these vectors in python?
#
# $V_1 = [2, 1]$

# %%
v1 = np.array([2, 1])
plot_vector([v1])

# %% [markdown]
# $V_2 = [2, 2]$

# %%
v2 = np.array([2, 2])
plot_vector([v2])

# %% [markdown]
# $V_3 = [2, 3]$

# %%
v3 = np.array([2, 3])
plot_vector([v3])

# %% [markdown]
# ## Assignment 2
#
# ### Display $A = [2, 3]$ and define $A$ based on standard basis

# %%
i = np.array([1, 0])
j = np.array([0, 1])
A = 2*i + 3*j
plot_vector([A])

# %% [markdown]
# ### Display $B = [-2, 3]$ and define $B$ based on standard basis

# %%
i = np.array([1, 0])
j = np.array([0, 1])
A = -2*i + 3*j
plot_vector([A])

# %% [markdown]
# ## Assigment 3
# ### Define basis for $\mathbb{R^4}$

# %%
# Define a basis for R4

print('e1 = ', np.array([1,0,0,0]))
print('e2 = ', np.array([0,1,0,0]))
print('e3 = ', np.array([0,0,1,0]))
print('e4 = ', np.array([0,0,0,1]))
# Out:
# e1 =  [1 0 0 0]
# e2 =  [0 1 0 0]
# e3 =  [0 0 1 0]
# e4 =  [0 0 0 1]

# %% [markdown]
# # Section 2: Vector operations
#
# ## 2.1 Vector addition

# %% [markdown]
# ## Assignment 4

# %% [markdown]
# ### Predict the result of addtion vectors $A[3, 1]$ and $B[2, 4]$

# %%
A = np.array([3, 1])
B = np.array([2, 4])

C = A + B

# %%
#@title Plot - Vector Addition
fig, ax = plt.subplots(figsize = (4,4))

vec = np.array([[[0, 0, A[0], A[1]]],
               [[0, 0, B[0], B[1]]],
               [[0, 0, C[0], C[1]]],
               [[A[0], A[1], B[0], B[1]]]])
color = ['r','b','g','b','r']

for i in range(vec.shape[0]):
    X,Y,U,V = zip(*vec[i,:,:])
    ax.quiver(X, Y, U, V, angles='xy', scale_units='xy', color = color[i], scale=1, alpha = .6)

ax.set_xlim([0, 10])
ax.set_ylim([0, 10])
ax.set_xlabel('x-axis', fontsize =16)
ax.set_ylabel('y-axis', fontsize =16)
ax.grid()

for i in range(3):
    ax.text(x = vec[i,0,2], y = vec[i,0,3], s = '(%.0d, %.0d)' %(vec[i,0,2],vec[i,0,3]), fontsize = 16)

# ax.text(x= vec[0,0,2]/2, y = vec[0,0,3]/2, s= '$u$', fontsize = 16)
# ax.text(x= 8, y = 9, s= '$v$', fontsize = 16)
# ax.text(x= 6, y = 5.5, s= '$u+v$', fontsize = 16)
# leg = ax.legend([A, B, C], ['$v$', '$u$', '$u+v$'], handlelength = 0, fontsize = 5, loc = 'upper left')
 
ax.set_title('Vector Addition', size = 18)
plt.show()

# %% [markdown]
# ### Predict the result of addtion vectors $A[2, 4]$ and $B[0, 1]$

# %%
A = np.array([2, 4])
B = np.array([0, 1])

C = A + B

# %%
#@title Plot - Vector Addition
fig, ax = plt.subplots(figsize = (4,4))

vec = np.array([[[0, 0, A[0], A[1]]],
               [[0, 0, B[0], B[1]]],
               [[0, 0, C[0], C[1]]],
               [[A[0], A[1], B[0], B[1]]]])
color = ['r','b','g','b','r']

for i in range(vec.shape[0]):
    X,Y,U,V = zip(*vec[i,:,:])
    ax.quiver(X, Y, U, V, angles='xy', scale_units='xy', color = color[i], scale=1, alpha = .6)

ax.set_xlim([0, 10])
ax.set_ylim([0, 10])
ax.set_xlabel('x-axis', fontsize =16)
ax.set_ylabel('y-axis', fontsize =16)
ax.grid()

for i in range(3):
    ax.text(x = vec[i,0,2], y = vec[i,0,3], s = '(%.0d, %.0d)' %(vec[i,0,2],vec[i,0,3]), fontsize = 16)

# ax.text(x= vec[0,0,2]/2, y = vec[0,0,3]/2, s= '$u$', fontsize = 16)
# ax.text(x= 8, y = 9, s= '$v$', fontsize = 16)
# ax.text(x= 6, y = 5.5, s= '$u+v$', fontsize = 16)
# leg = ax.legend([A, B, C], ['$v$', '$u$', '$u+v$'], handlelength = 0, fontsize = 5, loc = 'upper left')
 
ax.set_title('Vector Addition', size = 18)
plt.show()

# %% [markdown]
# ## 2.2 Scalar multiplication

# %% [markdown]
# ## Assignment 4

# %% [markdown]
# ### Predict the result of scalar multiplication vectors $A[1, 1]$ by $4$

# %%
A = np.array([1, 1])
m = 4

# %%
#@title Plot - Scalar Multiplication

fig, ax = plt.subplots(figsize=(4, 4))

vec = np.array([[[0, 0, A[0], A[1]]],
               [[0, 0, m * A[0], m * A[1]]]])
colors = ['r','b', 'r', 'b']

for i in range(vec.shape[0]):
    X,Y,U,V = zip(*vec[i,:,:])
    ax.quiver(X, Y, U, V, angles='xy', scale_units='xy', 
              color = color[i], scale=1, alpha = .6, zorder = -i)

s = ['$u$', '$3u$', '$v$', '$3v$']  
for i in range(vec.shape[0]):
    ax.text(x = vec[i,0, 2], y = vec[i, 0, 3], 
            s = '(%.0d, %.0d)' %(vec[i,0, 2], vec[i,0, 3]), fontsize = 16)
    # ax.text(x = vec[i,0, 2]/4, y = vec[i,0, 3]/2, 
    #         s = s[i], fontsize = 20)


ax.set_xlim([0, 10])
ax.set_ylim([0, 10])
ax.set_xlabel('x-axis', fontsize =16)
ax.set_ylabel('y-axis', fontsize =16)
ax.grid()

ax.set_title('Scalar Multiplication', size = 18)
plt.show()

# %% [markdown]
# ### Predict the result of scalar multiplication vectors $A[2, 3]$ by $2$

# %%
A = np.array([2, 3])
m = 2

# %%
#@title Plot - Scalar Multiplication

fig, ax = plt.subplots(figsize=(4, 4))

vec = np.array([[[0, 0, A[0], A[1]]],
               [[0, 0, m * A[0], m * A[1]]]])
colors = ['r','b', 'r', 'b']

for i in range(vec.shape[0]):
    X,Y,U,V = zip(*vec[i,:,:])
    ax.quiver(X, Y, U, V, angles='xy', scale_units='xy', 
              color = color[i], scale=1, alpha = .6, zorder = -i)

s = ['$u$', '$3u$', '$v$', '$3v$']  
for i in range(vec.shape[0]):
    ax.text(x = vec[i,0, 2], y = vec[i, 0, 3], 
            s = '(%.0d, %.0d)' %(vec[i,0, 2], vec[i,0, 3]), fontsize = 16)
    # ax.text(x = vec[i,0, 2]/4, y = vec[i,0, 3]/2, 
    #         s = s[i], fontsize = 20)


ax.set_xlim([0, 10])
ax.set_ylim([0, 10])
ax.set_xlabel('x-axis', fontsize =16)
ax.set_ylabel('y-axis', fontsize =16)
ax.grid()

ax.set_title('Scalar Multiplication', size = 18)
plt.show()

# %% [markdown]
# ## 2.3 A linear combination

# %% [markdown]
# ## Assignment 5

# %% [markdown]
# ### Display the linear combination of $A = [1, 0]$ and $B = [0, 1]$ based on $W = 2A + 3B$

# %%
A = np.array([1, 0])
B = np.array([0, 1])
m = 2
n = 3
w = m * A + n * B

# %%
#@title Plot - A linear combination
fig, ax = plt.subplots(figsize = (4,4))

Am = m * A
Bn = n * B

vec = np.array([[[0, 0, Am[0], Am[1]]],
               [[0, 0, Bn[0], Bn[1]]],
               [[0, 0, w[0], w[1]]],
               [[Am[0], Am[1], Bn[0], Bn[1]]]])
color = ['r','b','g','b','r']

for i in range(vec.shape[0]):
    X,Y,U,V = zip(*vec[i,:,:])
    ax.quiver(X, Y, U, V, angles='xy', scale_units='xy', color = color[i], scale=1, alpha = .6)

ax.set_xlim([0, 15])
ax.set_ylim([0, 15])
ax.set_xlabel('x-axis', fontsize =16)
ax.set_ylabel('y-axis', fontsize =16)
ax.grid()

for i in range(3):
    ax.text(x = vec[i,0,2], y = vec[i,0,3], s = '(%.0d, %.0d)' %(vec[i,0,2],vec[i,0,3]), fontsize = 16)

# ax.text(x= vec[0,0,2]/2, y = vec[0,0,3]/2, s= '$u$', fontsize = 16)
# ax.text(x= 8, y = 9, s= '$v$', fontsize = 16)
# ax.text(x= 6, y = 5.5, s= '$u+v$', fontsize = 16)
# leg = ax.legend([A, B, C], ['$v$', '$u$', '$u+v$'], handlelength = 0, fontsize = 5, loc = 'upper left')
 
ax.set_title('A linear combination', size = 18)
plt.show()

# %% [markdown]
# ### Display the linear combination of $A = [1, 2]$ and $B = [2, 1]$ based on $W = A + 2B$

# %%
A = np.array([1, 2])
B = np.array([2, 1])
m = 1
n = 2
w = m * A + n * B

# %%
#@title Plot - A linear combination
fig, ax = plt.subplots(figsize = (4,4))

Am = m * A
Bn = n * B

vec = np.array([[[0, 0, Am[0], Am[1]]],
               [[0, 0, Bn[0], Bn[1]]],
               [[0, 0, w[0], w[1]]],
               [[Am[0], Am[1], Bn[0], Bn[1]]]])
color = ['r','b','g','b','r']

for i in range(vec.shape[0]):
    X,Y,U,V = zip(*vec[i,:,:])
    ax.quiver(X, Y, U, V, angles='xy', scale_units='xy', color = color[i], scale=1, alpha = .6)

ax.set_xlim([0, 15])
ax.set_ylim([0, 15])
ax.set_xlabel('x-axis', fontsize =16)
ax.set_ylabel('y-axis', fontsize =16)
ax.grid()

for i in range(3):
    ax.text(x = vec[i,0,2], y = vec[i,0,3], s = '(%.0d, %.0d)' %(vec[i,0,2],vec[i,0,3]), fontsize = 16)

# ax.text(x= vec[0,0,2]/2, y = vec[0,0,3]/2, s= '$u$', fontsize = 16)
# ax.text(x= 8, y = 9, s= '$v$', fontsize = 16)
# ax.text(x= 6, y = 5.5, s= '$u+v$', fontsize = 16)
# leg = ax.legend([A, B, C], ['$v$', '$u$', '$u+v$'], handlelength = 0, fontsize = 5, loc = 'upper left')
 
ax.set_title('A linear combination', size = 18)
plt.show()

# %% [markdown]
# ## 2.4 Dot Product

# %% [markdown]
# ### Calculate dot product and plot $A = [2, 4]$ and $B = [-2, 4]$

# %%
v1 = np.array([2, 4])
v2 = np.array([-2, 4])

print('dot product:', np.dot(v1, v2))
plot_vector([v1, v2])
# Out:
# dot product: 12

# %% [markdown]
# ### Calculate dot product and plot $A = [2, 4]$ and $B = [-2, -4]$

# %%
v1 = np.array([2, 4])
v2 = np.array([-2, -4])

print('dot product:', np.dot(v1, v2))
plot_vector([v1, v2])
# Out:
# dot product: -20

# %% [markdown]
# ### Calculate dot product and plot $A = [2, 4]$ and $B = [2, -4]$

# %%
v1 = np.array([2, 4])
v2 = np.array([2, -4])

print('dot product:', np.dot(v1, v2))
plot_vector([v1, v2])
# Out:
# dot product: -12

# %% [markdown]
# ### Calculate dot product and plot $A = [2, 4]$ and $B = [2, 4]$

# %%
v1 = np.array([2, 4])
v2 = np.array([2, 4])

print('dot product:', np.dot(v1, v2))
plot_vector([v1, v2])
# Out:
# dot product: 20

# %% [markdown]
# ### Calculate dot product and plot $A = [-2, -4]$ and $B = [-2, -4]$

# %%
v1 = np.array([-2, -4])
v2 = np.array([-2, -4])

print('dot product:', np.dot(v1, v2))
plot_vector([v1, v2])
# Out:
# dot product: 20

# %% [markdown]
# # 1.5 An overview of three types of data science distance measures
#
# ## Given	the	following	points	compute	the	distance by	using:

# %% [markdown]
# | Points | X | Y |
# | :--- | :-----------: | ---: |
# | P1 | 6 | 3 |
# | P2 | 2 | 2 |
# | P3 | 3 | 4 |
#
# ![Screenshot 2022-09-14 at 20.07.43.png](data:image/png;base64,...)

# %% [markdown]
# ### a) Manhattan	distance	(provide	the	formula)

# %%
p1 = np.array([6, 3])
p2 = np.array([2, 2])
p3 = np.array([3, 4])
print(abs(p1[0] - p1[0]) + abs(p1[1] - p1[1]), "   ", abs(p1[0] - p2[0]) + abs(p1[1] - p2[1]), "   ", abs(p1[0] - p3[0]) + abs(p1[1] - p3[1]))
print(abs(p2[0] - p1[0]) + abs(p2[1] - p1[1]), "   ", abs(p2[0] - p2[0]) + abs(p2[1] - p2[1]), "   ", abs(p2[0] - p3[0]) + abs(p2[1] - p3[1]))
print(abs(p3[0] - p1[0]) + abs(p3[1] - p1[1]), "   ", abs(p3[0] - p2[0]) + abs(p3[1] - p2[1]), "   ", abs(p3[0] - p3[0]) + abs(p3[1] - p3[1]))
# Out:
# 0     5     4
# 5     0     3
# 4     3     0

# %%
# plot_vector([p1, p2])

# %% [markdown]
# ### b) Euclidean	distance (provide	the	formula)

# %%
p1 = np.array([6, 3])
p2 = np.array([2, 2])
p3 = np.array([3, 4])

print(np.sqrt(np.sum(np.square(p1 - p1))), "   ", np.sqrt(np.sum(np.square(p1 - p2))), "   ", np.sqrt(np.sum(np.square(p1 - p3))))
print(np.sqrt(np.sum(np.square(p2 - p1))), "   ", np.sqrt(np.sum(np.square(p2 - p2))), "   ", np.sqrt(np.sum(np.square(p2 - p3))))
print(np.sqrt(np.sum(np.square(p3 - p1))), "   ", np.sqrt(np.sum(np.square(p3 - p2))), "   ", np.sqrt(np.sum(np.square(p3 - p3))))
# Out:
# 0.0     4.123105625617661     3.1622776601683795
# 4.123105625617661     0.0     2.23606797749979
# 3.1622776601683795     2.23606797749979     0.0

# %% [markdown]
# ### c) Cosine Similarity (provide the formula)

# %%
p1 = np.array([6, 3])
p2 = np.array([2, 2])
p3 = np.array([3, 4])

cosine_similarity_p1_p1 = np.dot(p1, p1)/(np.sqrt(np.square(p1[0]) + np.square(p1[1]))*np.sqrt(np.square(p1[0]) + np.square(p1[1])))
cosine_similarity_p1_p2 = np.dot(p1, p2)/(np.sqrt(np.square(p1[0]) + np.square(p1[1]))*np.sqrt(np.square(p2[0]) + np.square(p2[1])))
cosine_similarity_p1_p3 = np.dot(p1, p3)/(np.sqrt(np.square(p1[0]) + np.square(p1[1]))*np.sqrt(np.square(p3[0]) + np.square(p3[1])))
cosine_similarity_p2_p1 = np.dot(p2, p1)/(np.sqrt(np.square(p2[0]) + np.square(p2[1]))*np.sqrt(np.square(p1[0]) + np.square(p1[1])))
cosine_similarity_p2_p2 = np.dot(p2, p2)/(np.sqrt(np.square(p2[0]) + np.square(p2[1]))*np.sqrt(np.square(p2[0]) + np.square(p2[1])))
cosine_similarity_p2_p3 = np.dot(p2, p3)/(np.sqrt(np.square(p2[0]) + np.square(p2[1]))*np.sqrt(np.square(p3[0]) + np.square(p3[1])))
cosine_similarity_p3_p1 = np.dot(p3, p1)/(np.sqrt(np.square(p3[0]) + np.square(p3[1]))*np.sqrt(np.square(p1[0]) + np.square(p1[1])))
cosine_similarity_p3_p2 = np.dot(p3, p2)/(np.sqrt(np.square(p3[0]) + np.square(p3[1]))*np.sqrt(np.square(p2[0]) + np.square(p2[1])))
cosine_similarity_p3_p3 = np.dot(p3, p3)/(np.sqrt(np.square(p3[0]) + np.square(p3[1]))*np.sqrt(np.square(p3[0]) + np.square(p3[1])))

print(cosine_similarity_p1_p1, cosine_similarity_p1_p2, cosine_similarity_p1_p3)
print(cosine_similarity_p2_p1, cosine_similarity_p2_p2, cosine_similarity_p2_p3)
print(cosine_similarity_p3_p1, cosine_similarity_p3_p2, cosine_similarity_p3_p3)
# Out:
# 0.9999999999999999 0.9486832980505137 0.8944271909999157
# 0.9486832980505137 0.9999999999999998 0.9899494936611665
# 0.8944271909999157 0.9899494936611665 1.0

# %% [markdown]
# # 1.6 Hands-on Project: Similarity

# %%
import pandas as pd

df = pd.read_csv('https://github.com/aaubs/ds-master/blob/main/data/CarPrice_Assignment.csv')
df = df[['car_ID', 'CarName', 'carlength', 'enginesize', 'horsepower', 'citympg', 'highwaympg', 'price']]
df.head(20)
# Out:
#     car_ID                   CarName  carlength  enginesize  horsepower  \
# 0        1        alfa-romero giulia      168.8         130         111
# 1        2       alfa-romero stelvio      168.8         130         111
# 2        3  alfa-romero Quadrifoglio      171.2         152         154
# 3        4               audi 100 ls      176.6         109         102
# 4        5                audi 100ls      176.6         136         115
# 5        6                  audi fox      177.3         136         110
# 6        7                audi 100ls      192.7         136         110
# 7        8                 audi 5000      192.7         136         110
# 8        9                 audi 4000      192.7         131         140
# 9       10       audi 5000s (diesel)      178.2         131         160
# 10      11                  bmw 320i      176.8         108         101
# 11      12                  bmw 320i      176.8         108         101
# ...

# %% [markdown]
# ## 1.6.1 Define the vectors
#
# ## Define three 3D vectors based on car dataset?

# %%
car_1 = df.iloc[:, 2:5].to_numpy()[5]
car_2 = df.iloc[:, 2:5].to_numpy()[6]
car_3 = df.iloc[:, 2:5].to_numpy()[17]

# %% [markdown]
# ## 1.6.2 Calculate the length of vectors

# %%
vector_car_1_length = np.sqrt(np.square(car_1[0]) + np.square(car_1[1]) + np.square(car_1[2]))
vector_car_2_length = np.sqrt(np.square(car_2[0]) + np.square(car_2[1]) + np.square(car_1[2]))
vector_car_3_length = np.sqrt(np.square(car_3[0]) + np.square(car_3[1]) + np.square(car_1[2]))

# %% [markdown]
# ## 1.6.3 Calculate the similarity between vectors using
#
#  - Cosine Similarity
#  - Manhattan distance
#  - Euclidean distance

# %%
car_1_n = np.array([df.iloc[:, 2:5].to_numpy()[5][0]/df['carlength'].max(), df.iloc[:, 2:5].to_numpy()[5][1]/df['enginesize'].max(), df.iloc[:, 2:5].to_numpy()[5][2]/df['horsepower'].max()])
car_2_n = np.array([df.iloc[:, 2:5].to_numpy()[6][0]/df['carlength'].max(), df.iloc[:, 2:5].to_numpy()[6][1]/df['enginesize'].max(), df.iloc[:, 2:5].to_numpy()[6][2]/df['horsepower'].max()])
car_3_n = np.array([df.iloc[:, 2:5].to_numpy()[17][0]/df['carlength'].max(), df.iloc[:, 2:5].to_numpy()[17][1]/df['enginesize'].max(), df.iloc[:, 2:5].to_numpy()[17][2]/df['horsepower'].max()])

# %%
car_1_n = df.iloc[:, 2:5].to_numpy()[5]
car_2_n = df.iloc[:, 2:5].to_numpy()[6]
car_3_n = df.iloc[:, 2:5].to_numpy()[17]

# %%
vector_car_1_length_n = np.sqrt(np.square(car_1_n[0]) + np.square(car_1_n[1]) + np.square(car_1_n[2]))
vector_car_2_length_n = np.sqrt(np.square(car_2_n[0]) + np.square(car_2_n[1]) + np.square(car_1_n[2]))
vector_car_3_length_n = np.sqrt(np.square(car_3_n[0]) + np.square(car_3_n[1]) + np.square(car_1_n[2]))

# %%
cosine_similarity12 = np.dot(car_1, car_2)/(vector_car_1_length*vector_car_2_length)
cosine_similarity23 = np.dot(car_2, car_3)/(vector_car_2_length*vector_car_3_length)
cosine_similarity13 = np.dot(car_1, car_3)/(vector_car_1_length*vector_car_3_length)

print("car 1 vector: ", car_1)
print("car 2 vector: ", car_2)
print("car 3 vector: ", car_3)
print('Similarity Score of car_1 and car_2: ', cosine_similarity12)
print('Similarity Score of car_2 and car_3: ', cosine_similarity23)
print('Similarity Score of car_1 and car_3: ', cosine_similarity13)
# Out:
# car 1 vector:  [177.3 136.  110. ]
# car 2 vector:  [192.7 136.  110. ]
# car 3 vector:  [197. 209. 182.]
# Similarity Score of car_1 and car_2:  0.9991360742830357
# Similarity Score of car_2 and car_3:  1.0795245516111647
# Similarity Score of car_1 and car_3:  1.0884104970197748

# %%
cosine_similarity12 = np.dot(car_1_n, car_2_n)/(vector_car_1_length_n*vector_car_2_length_n)
cosine_similarity23 = np.dot(car_2_n, car_3_n)/(vector_car_2_length_n*vector_car_3_length_n)
cosine_similarity13 = np.dot(car_1_n, car_3_n)/(vector_car_1_length_n*vector_car_3_length_n)

print("car 1 vector: ", car_1)
print("car 2 vector: ", car_2)
print("car 3 vector: ", car_3)
print('Similarity Score of car_1 and car_2: ', cosine_similarity12)
print('Similarity Score of car_2 and car_3: ', cosine_similarity23)
print('Similarity Score of car_1 and car_3: ', cosine_similarity13)
# Out:
# car 1 vector:  [177.3 136.  110. ]
# car 2 vector:  [192.7 136.  110. ]
# car 3 vector:  [197. 209. 182.]
# Similarity Score of car_1 and car_2:  0.9992883154392319
# Similarity Score of car_2 and car_3:  1.059208480317443
# Similarity Score of car_1 and car_3:  1.0670364473349445

# %%
def manhattan_distance(x1, x2):
    return abs(x1[0] - x2[0]) + abs(x1[1] - x2[1])

# %%
print('Similarity Score of car_1 and car_2: ', manhattan_distance(car_1, car_2))
print('Similarity Score of car_2 and car_3: ', manhattan_distance(car_2, car_3))
print('Similarity Score of car_1 and car_3: ', manhattan_distance(car_1, car_3))
# Out:
# Similarity Score of car_1 and car_2:  15.399999999999977
# Similarity Score of car_2 and car_3:  77.30000000000001
# Similarity Score of car_1 and car_3:  92.69999999999999

# %%
def euclidean_distance(point1, point2):
    return np.sqrt(np.sum(np.square(point1 - point2)))

# %%
print('Similarity Score of car_1 and car_2: ', euclidean_distance(car_1, car_2))
print('Similarity Score of car_2 and car_3: ', euclidean_distance(car_2, car_3))
print('Similarity Score of car_1 and car_3: ', euclidean_distance(car_1, car_3))
# Out:
# Similarity Score of car_1 and car_2:  15.399999999999977
# Similarity Score of car_2 and car_3:  102.62304809349604
# Similarity Score of car_1 and car_3:  104.40828511186265
