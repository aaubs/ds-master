# %% [markdown]
# <a href="https://colab.research.google.com/github/aaubs/ds-master/blob/main/notebooks/M1_Linear_Algebra_Matrices_V6_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Section 1 Intro to matrices

# %%
# @title Basic imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import ticker

# Display options
from IPython.display import display
pd.options.display.max_columns = None

np.set_printoptions(threshold=30)

# Plots style
from cycler import cycler

matplotlib.rcParams['lines.linewidth'] = 3
matplotlib.rcParams['lines.markersize'] = 10

matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['xtick.color'] = '#A9A9A9'
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['ytick.color'] = '#A9A9A9'

matplotlib.rcParams['grid.color'] = '#ffffff'

matplotlib.rcParams['axes.facecolor'] = '#ffffff'

matplotlib.rcParams['axes.spines.left'] = False
matplotlib.rcParams['axes.spines.right'] = False
matplotlib.rcParams['axes.spines.top'] = False
matplotlib.rcParams['axes.spines.bottom'] = False

matplotlib.rcParams['axes.prop_cycle'] = cycler(color=['#2EBCE7', '#84EE29', '#FF8177'])

# %% [markdown]
# 1. Define matrix A in python
# $$
# \mathbf{A} =
# \begin{bmatrix}
# 4 & 0 \\\\
# 1 & -9 \
# \end{bmatrix}
# $$

# %% [markdown]
# ================================================================================

# %% [markdown]
# 2. Define matrix B in python
# $$
# \mathbf{B} =
# \begin{bmatrix}
# 4 & 2 & 9\\\\
# 5 & 1 & 0\\\\
# 3 & 4 & 7\
# \end{bmatrix}
# $$

# %% [markdown]
# ================================================================================

# %% [markdown]
# 3. Read data and define Matrix C based on these columns [enginesize', 'horsepower', 'citympg']

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/HamidBekamiri/Linear-Algebra/main/CarPrice_Assignment.csv')
df = df[['car_ID', 'CarName', 'carlength', 'enginesize', 'horsepower', 'citympg', 'highwaympg', 'price']]
df.head(2)
# Out:
#    car_ID              CarName  carlength  enginesize  horsepower  citympg  \
# 0       1   alfa-romero giulia      168.8         130         111       21
# 1       2  alfa-romero stelvio      168.8         130         111       21
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0

# %% [markdown]
# ================================================================================

# %% [markdown]
# 4. Check shape A, B, and C

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Section 2 Operations and Manipulations on Matrices

# %% [markdown]
# 5. Add A and B and check sahpe of matrices?
#
# $$
# \mathbf{A} =
# \begin{bmatrix}
# 4 & 2 & 9\\\\
# 5 & 1 & 0\\\\
# 3 & 4 & 7\
# \end{bmatrix}
# $$
#
# $$
# \mathbf{B} =
# \begin{bmatrix}
# 4 & 2 & 9\\\\
# 5 & 1 & 0\\\\
# 3 & 4 & 7\
# \end{bmatrix}
# $$

# %% [markdown]
# ================================================================================

# %% [markdown]
# 6. Multiply A by 2 and check the output matrix shape?

# %% [markdown]
# ================================================================================

# %% [markdown]
# 7. Multiply A by 3 and check the output matrix shape?

# %% [markdown]
# ================================================================================

# %% [markdown]
# 8. For Matrix C in 3
#
# > - 8.1 check shape

# %% [markdown]
# > - 8.2 Transpose Matrix C

# %% [markdown]
# > - 8.3 check C.T shape

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Section 2.4 Matrix Product

# %% [markdown]
# 9. Calculate dot product of Matrix A and Vector w?
#
#
# $$
# \mathbf{A} =
# \begin{bmatrix}
# 1 & 2 & 2\\\\
# 5 & 6 & 2\\\\
# 7 & 8 & 2\
# \end{bmatrix}
# $$.
# $$
# \mathbf{w} = \begin{bmatrix}
# 3 \\\\
# 4 \\\\
# 2
# \end{bmatrix}
# $$

# %%
# Out:
# array([15, 43, 57])

# %% [markdown]
# ================================================================================

# %% [markdown]
# 10. Let's say:
#
# **𝑆𝑎𝑙𝑒𝑠 =  𝑊1 * TV + 𝑊2 * 𝑅𝑎𝑑𝑖𝑜 + + 𝑊3 * 𝑁𝑒𝑤𝑠𝑝𝑎𝑝𝑒𝑟**
#
# Predict sales based on 'TV', 'Radio', 'Newspaper' columns?
#
#
# $$
# \mathbf{w} = \begin{bmatrix}
# 3 \\\\
# 4 \\\\
# 2
# \end{bmatrix}
# $$

# %%
df_advertising = pd.read_csv('https://raw.githubusercontent.com/HamidBekamiri/Linear-Algebra/main/df_advertising.csv')
df_advertising = df_advertising[['TV', 'Radio', 'Newspaper', 'Sales']]
df_advertising.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
# Out:
# array([[3],
#        [4],
#        [4]])

# %%
A =

# %%
# Out:
# array([[1118.3],
#        [ 471.1],
#        [ 512.4],
#        [ 853.7],
#        [ 819.2],
#        [ 521.7],
#        [ 397.7],
#        [ 485.4],
#        [  38.2],
#        [ 694.6],
#        [ 318.3],
#        [ 756.1],
#        [ 475.4],
#        [ 351.7],
#        [ 927.9],
#        [ 988.6],
#        [ 805.8],
#        [1225.8],
#        [ 362.8],
#        [ 613.9],
#        [ 979.6],
#        [ 826.6],
#        [ 301.6],
#        [ 857.3],
#        [ 310.5],
#        [ 880.7],
#        [ 596.3],
#        [ 878.7],
#        [ 946.4],
#        [ 439. ],
#        [1164.7],
#        [ 562.7],
#        [ 417.6],
#        [ 878. ],
#        [ 322.3],
#        [ 922.5],
#        [ 995.9],
#        [ 604.5],
#        [ 376.5],
#        [ 962.8],
#        [ 823.1],
#        [ 819.4],
#        [ 998.8],
#        [ 759.9],
#        [ 351.3],
#        [ 741.3],
#        [ 451.5],
#        [ 959.7],
#        [ 944.4],
#        [ 394.7],
#        [ 750.2],
#        [ 354. ],
#        [ 974.4],
#        [ 967.4],
#        [ 966.9],
#        [1034.3],
#        [ 299.9],
#        [ 551.8],
#        [ 981.6],
#        [ 787.3],
#        [ 254.1],
#        [1173.5],
#        [ 889.1],
#        [ 460.1],
#        [ 680.1],
#        [ 247.8],
#        [ 201.7],
#        [ 516.7],
#        [ 866.2],
#        [ 934.8],
#        [ 874.5],
#        [ 513.4],
#        [ 289.6],
#        [ 536.2],
#        [ 791. ],
#        [ 583.1],
#        [ 171.7],
#        [ 532.3],
#        [ 173.4],
#        [ 471.2],
#        [ 425.2],
#        [ 883.4],
#        [ 437.1],
#        [ 525.6],
#        [ 947.7],
#        [ 916. ],
#        [ 402.9],
#        [ 747.3],
#        [ 660.5],
#        [ 726.2],
#        [ 459.7],
#        [ 223.8],
#        [1023.1],
#        [1187.9],
#        [ 421.8],
#        [ 827.9],
#        [ 630.4],
#        [ 726.7],
#        [1243.1],
#        [ 756. ],
#        [ 883.6],
#        [1438. ],
#        [ 966.6],
#        [ 704.1],
#        [ 873. ],
#        [ 835.3],
#        [ 237.8],
#        [ 365.2],
#        [ 143.3],
#        [ 895.8],
#        [ 936.2],
#        [ 969.9],
#        [ 598.3],
#        [ 754. ],
#        [ 559.8],
#        [ 576.1],
#        [ 577.2],
#        [ 291.6],
#        [ 841.5],
#        [ 211.4],
#        [ 715.9],
#        [ 344.8],
#        [ 744. ],
#        [ 557.3],
#        [1114.5],
#        [ 412.4],
#        [ 381.4],
#        [ 277.4],
#        [ 869.7],
#        [ 399.2],
#        [ 195.3],
#        [ 979.2],
#        [ 142.4],
#        [ 973.8],
#        [ 527.5],
#        [ 366.9],
#        [ 270. ],
#        [1175.5],
#        [ 314.6],
#        [ 737.1],
#        [ 339.8],
#        [1025.1],
#        [ 945.9],
#        [ 474.2],
#        [ 503.4],
#        [ 464.5],
#        [ 784.3],
#        [1102.8],
#        [ 322.8],
#        [ 319.7],
#        [1045.7],
#        [ 591.4],
#        [ 742.8],
#        [ 823.5],
#        [ 685.8],
#        [  81.5],
#        [ 657.7],
#        [ 551.8],
#        [ 363.5],
#        [ 607.1],
#        [ 712.7],
#        [ 597.5],
#        [ 740. ],
#        [ 667.3],
#        [ 432. ],
#        [1056.3],
#        [ 290.5],
#        [ 718.8],
#        [ 971. ],
#        [ 920.9],
#        [ 270. ],
#        [ 766.7],
#        [ 207.2],
#        [ 584.8],
#        [ 733.2],
#        [1193.5],
#        [ 947.2],
#        [ 682.6],
#        [ 934.1],
#        [ 607.2],
#        [ 513.4],
#        [ 786.7],
#        [ 310.2],
#        [1322. ],
#        [ 966.6],
#        [ 873.8],
#        [ 533.3],
#        [ 760.9],
#        [ 928.4],
#        [ 198.1],
#        [ 306.1],
#        [ 293.7],
#        [ 194.4],
#        [ 682.8],
#        [ 615.5],
#        [ 184.6],
#        [ 334.6],
#        [ 593.8],
#        [1283.6],
#        [ 765.5]])

# %% [markdown]
# ================================================================================

# %% [markdown]
# 11. Check shape of Matrices in each part?

# %%
# Out:
# (200, 3)

# %%
# Out:
# (3, 1)

# %%
# Out:
# (200, 1)

# %% [markdown]
# ================================================================================

# %% [markdown]
# 12. A car company sells 3 types of cars.
# - Car type 1 cost 200K DKK each
# - Car type 2  cost 400k DKK each
# - Car type 3  cost 120K DKK each
#
# And this is how many they sold in 5 days:

# %% [markdown]
# ![](https://raw.githubusercontent.com/HamidBekamiri/Linear-Algebra/main/images/multiply_matrix_example.png)
#
#
# Now think about this ... the value of sales for Monday is calculated this way:
#
# Car type 1 * Value type 1 + Car type 2 * Value type 2 + Car type 3 * Value type 3
#
# So it is, in fact, the **"dot product"** of prices and how many were sold:

# %% [markdown]
# Calculate the value of the sales of three different cars for Mon, Tue, and Wed?

# %%
# Out:
# array([[7040, 3880, 1600]])

# %% [markdown]
# ================================================================================

# %% [markdown]
# 12. Calculate Covariance Matrix of 'TV', 'Radio', 'Newspaper', 'Sales' in advertising dataset?
#
# > - 12.1 Develop the covariance method from scratch

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Out:
# (200, 4)

# %%
# Out:
# (4, 200)

# %%
# Out:
# array([[7370.94989322,   69.86249246,  105.91945226,  350.39019472],
#        [  69.86249246,  220.42774271,  114.49697889,   44.63568844],
#        [ 105.91945226,  114.49697889,  474.30832563,   25.94139196],
#        [ 350.39019472,   44.63568844,   25.94139196,   27.22185302]])

# %% [markdown]
# > - 12.2 Check result by NumPy covariance method

# %%
# Out:
# array([[7370.94989322,   69.86249246,  105.91945226,  350.39019472],
#        [  69.86249246,  220.42774271,  114.49697889,   44.63568844],
#        [ 105.91945226,  114.49697889,  474.30832563,   25.94139196],
#        [ 350.39019472,   44.63568844,   25.94139196,   27.22185302]])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Section 2.5 Inverse of a Matrix

# %% [markdown]
# 13. Calculate inverse of D
#
# \begin{align}
#         D = \begin{bmatrix}
# 2 & 5 \\
# 3 & 4
# \end{bmatrix}
#     \end{align}

# %% [markdown]
# > - 12.1 Develop the inverse of D from scratch

# %%
# Out:
# array([[-0.57142857,  0.71428571],
#        [ 0.42857143, -0.28571429]])

# %% [markdown]
# > - 12.2 Check result by NumPy inverse method

# %%
# Out:
# [[-0.57142857  0.71428571]
#  [ 0.42857143 -0.28571429]]

# %% [markdown]
# ================================================================================

# %% [markdown]
# 14. Mathilde inherits DKK 210,000 and after watching many YouTube videos about investing, she distributes money between Equities, ETFs and Investment Associations. After one year, it has yielded the following returns: equities 9.4%, ETF 4.6%, mutual funds 4.25%. In total, Mathilde earns DKK 13,360 after 1 year. In addition, we know that 50,000 more were invested in ETFs than Investment Associations. So we have:
#
# ![](https://raw.githubusercontent.com/HamidBekamiri/Linear-Algebra/main/images/Matrix.png)

# %%
# Out:
# array([[ -0.88944724,  20.10050251,  -0.03517588],
#        [  0.94472362, -10.05025126,   0.51758794],
#        [  0.94472362, -10.05025126,  -0.48241206]])

# %%
# Out:
# array([[210000],
#        [ 13360],
#        [ 50000]])

# %%
# Out:
# array([[80000.],
#        [90000.],
#        [40000.]])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Section 2.6 Matrix Determinant
#
# 15. Calculate determinant of B:
#
# \begin{align}
#         B = \begin{bmatrix}
# -2 & 1 \\
# 4 & 6
# \end{bmatrix}
#     \end{align}

# %%
# Out:
# -15.999999999999998

# %% [markdown]
# # Section 2.7 Eigenvalues & Eigenvectors

# %% [markdown]
# 16. Find Eigenvalues for matrix B

# %% [markdown]
# Put in the values we know:
#
# \begin{align}
# | A − λI | = 0 \\\
#         det(\begin{bmatrix}
# -2 & 1 \\
# 4 & 6
# \end{bmatrix}  - λ
#         \begin{bmatrix}
# 1 & 0 \\
# 0 & 1
# \end{bmatrix})
# = det(        \begin{bmatrix}
# -2-λ & 1 \\
# 4 & 6-λ
# \end{bmatrix}) = (-2-λ)(6-λ) - 4 = λ^2 - 4λ - 12 = 0
# \end{align}

# %%
# roots of quadratic equation
import IPython
iframe_1 = '<iframe src="https://www.mathsisfun.com/quadratic-equation-solver.html" width="1000px" height="500px" style="border: 1px solid #ccc" frameborder=0></iframe>'
IPython.display.HTML(iframe_1)
# Out:
# <iframe src="https://www.mathsisfun.com/quadratic-equation-solver.html" width="1000px" height="500px" style="border: 1px solid #ccc" frameborder=0></iframe>

# %% [markdown]
# \begin{align}
# λ = 6 \\\
# λ = -2
# \end{align}

# %% [markdown]
# ================================================================================

# %% [markdown]
# 17. Find Eigenvectors for matrix B

# %%
print("eigvals: ", eigvals)
print("eigvecs_u: ", u)
print("eigvecs_v: ", v)
# Out:
# eigvals:  [-2.47213595  6.47213595]
# eigvecs_u:  [[-0.90427877]
#  [ 0.42694252]]
# eigvecs_v:  [[-0.11722026]
#  [-0.99310594]]

# %%
import numpy as np

v = eigvecs[:, 1].reshape(-1, 1)


y = B @ v
plt.quiver(0, 0, v[0], v[1], color="#2EBCE7", angles='xy',
           scale_units='xy', scale=1)
plt.quiver(0, 0, y[0], y[1], color="#00E64E", angles='xy',
           scale_units='xy', scale=1)
# [...] Add axes, styles, vector names

# Assure that ticks are displayed with a specific step
ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

plt.text(-0.5, 0.2, r'$\vec{v}$', color="#2EBCE7", size=18)
plt.text(0.3, -0.5, r'$\vec{y}$', color="#00E64E", size=18)

# draw axes
plt.axhline(0, c='#A9A9A9')
plt.axvline(0, c='#A9A9A9')

plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## How big is the fish?
#
# Helpful code:
#
# ```X_centered = X - X.mean(axis=0)```
#
# ```X_transformed = X_centered @ np.array([u,v])```
#
#
# ```x=X_transformed[0, :].reshape(1, -1)[0]```
#
# ```y=X_transformed[1, :].reshape(1, -1)[0]```
#
# ```labels=df[['Species']]['Species']```

# %%
import seaborn as sns; sns.set()
import plotly.express as px

# %%
df = pd.read_csv('https://raw.githubusercontent.com/aaubs/ds-master/main/data/Fish.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %% [markdown]
# ### Fish 3d plot

# %%
fig = px.scatter_3d(df,
                    x='Length2',
                    y='Width',
                    z='Height',
                    color='Species')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f8b023ed-b9fa-4a4d-a248-1c0f01aa8478" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8b023ed-b9fa-4a4d-a248-1c0f01aa8478")) {                    Plotly.newPlot(                        "f8b023ed-b9fa-4a4d-a248-1c0f01aa8478",                        [{"hovertemplate":"Species=Bream<br>Length2=%{x}<br>Width=%{y}<br>Height=%{z}<extra></extra>","legendgroup":"Bream","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Bream","scene":"scene","showlegend":true,"x":[25.4,26.3,26.5,29.0,29.0,29.7,29.7,30.0,30.0,30.7,31.0,31.0,31.5,32.0,32.0,32.0,33.0,33.0,33.5,33.5,34.0,34.0,34.5,35.0,35.0,35.0,35.0,36.0,36.0,37.0,38.5,38.5,39.5,41.0,41.0],"y":[4.02,4.3056,4.6961,4.4555,5.134,4.9274,5.2785,4.69,4.8438,4.9594,5.1042,4.8146,4.368,5.0728,5.1708,5.58,5.2854,5.1975,5.1338,5.7276,5.5695,5.3704,5.2801,6.1306,5.589,6.0532,6.09,5.8515,6.1984,6.603,6.3063,6.292,6.7497,6.7473,6.3705],"z":[11.52,12.48,12.3778,12.73,12.444,13.6024,14.1795,12.67,14.0049,14.2266,14.2628,14.3714,13.7592,13.9129,14.9544,15.438,14.8604,14.938,15.633,14.4738,15.1285,15.9936,15.5227,15.4686,16.2405,16.36,16.3618,16.517,16.8896,18.957,18.0369,18.084,18.7542,18.6354,17.6235],"type":"scatter3d"},{"hovertemplate":"Species=Roach<br>Length2=%{x}<br>Width=%{y}<br>Height=%{z}<extra></extra>","legendgroup":"Roach","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Roach","scene":"scene","showlegend":true,"x":[14.1,18.2,18.8,19.8,20.0,20.5,20.8,21.0,22.0,22.0,22.5,22.5,22.5,24.0,23.4,23.5,25.2,26.0,27.0,31.7],"y":[2.268,2.8217,2.9044,3.1746,3.5742,3.3516,3.3957,3.2943,3.7544,3.5478,3.8203,3.325,3.8,3.8352,3.6312,4.1272,3.906,4.4968,4.7736,5.355],"z":[4.1472,5.2983,5.5756,5.6166,6.216,6.4752,6.1677,6.1146,5.8045,6.6339,7.0334,6.55,6.4,7.5344,6.9153,7.3968,7.0866,8.8768,8.568,9.485],"type":"scatter3d"},{"hovertemplate":"Species=Whitefish<br>Length2=%{x}<br>Width=%{y}<br>Height=%{z}<extra></extra>","legendgroup":"Whitefish","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Whitefish","scene":"scene","showlegend":true,"x":[26.0,26.5,28.0,31.0,36.4,40.0],"y":[4.2476,4.2485,4.6816,6.562,6.5736,6.525],"z":[8.3804,8.1454,8.778,10.744,11.7612,12.354],"type":"scatter3d"},{"hovertemplate":"Species=Parkki<br>Length2=%{x}<br>Width=%{y}<br>Height=%{z}<extra></extra>","legendgroup":"Parkki","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Parkki","scene":"scene","showlegend":true,"x":[14.7,15.5,17.7,19.0,20.0,20.7,20.7,21.5,23.0,25.0,26.0],"y":[2.3265,2.3142,2.673,2.9181,3.2928,3.2944,3.4104,3.1571,3.6636,4.144,4.234],"z":[6.8475,6.5772,7.4052,8.3922,8.8928,8.5376,9.396,9.7364,10.3458,11.088,11.368],"type":"scatter3d"},{"hovertemplate":"Species=Perch<br>Length2=%{x}<br>Width=%{y}<br>Height=%{z}<extra></extra>","legendgroup":"Perch","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Perch","scene":"scene","showlegend":true,"x":[8.4,13.7,15.0,16.2,17.4,18.0,18.7,19.0,19.6,20.0,21.0,21.0,21.0,21.3,22.0,22.0,22.0,22.0,22.0,22.5,22.5,22.7,23.0,23.5,24.0,24.0,24.6,25.0,25.6,26.5,27.3,27.5,27.5,27.5,28.0,28.7,30.0,32.8,34.5,35.0,36.5,36.0,37.0,37.0,39.0,39.0,39.0,40.0,40.0,40.0,40.0,42.0,43.0,43.0,43.5,44.0],"y":[1.408,1.9992,2.432,2.6316,2.9415,3.3216,3.1234,3.0502,3.0368,2.772,3.555,3.3075,3.6675,3.534,3.4075,3.525,3.525,3.525,3.995,3.624,3.624,3.63,3.626,3.725,3.723,3.825,4.1658,3.6835,4.239,4.144,5.1373,4.335,4.335,4.5662,4.2042,4.6354,4.7716,6.018,6.3875,7.7957,6.864,6.7408,6.2646,6.3666,7.4934,6.003,7.3514,7.1064,7.225,7.4624,6.63,6.8684,7.2772,7.4165,8.142,7.5958],"z":[2.112,3.528,3.824,4.5924,4.588,5.2224,5.1992,5.6358,5.1376,5.082,5.6925,5.9175,5.6925,6.384,6.11,5.64,6.11,5.875,5.5225,5.856,6.792,5 ...

# %% [markdown]
# ### Plan of exercise
#
# 1. Check covariance Matrix
# 2. Calcualte Eigenvectors and Eigenvalues
# 3. Select M (< Ds) Eigenvectors with highest Eigenvalues
# 4. Project data points to these Eigenvectors
#   * Calculate center of the points: X-X.mean()
#   * Calculate Dot product of X_centered by eigenvectors

# %%
fig = px.scatter(x=x, y=y, color=labels)
fig.show()

# %% [markdown]
# 18. Calculate PCA for this data
#
# \begin{align}
#         x = \begin{bmatrix}
# -4 & -3 & -2 & -1 & 0 & 1 & 2 & 3 & 4\
# \end{bmatrix}
# \\\
# y = \begin{bmatrix}
# -5 & -2 & -2.8 & -1.1 & 0 & 1.5 & 2.8 & 3.2 & 4.1\
# \end{bmatrix}
#     \end{align}

# %% [markdown]
# **1. Check covariance Matrix:**

# %%
import numpy as np
import matplotlib.pyplot as plt

x = 
y = 

plt.axhline(0, c='#d6d6d6', zorder=0)
plt.axvline(0, c='#d6d6d6', zorder=0)
plt.plot(x, y)


plt.show()

# %%
# Out:
# (9, 2)

# %%
# Out:
# array([[-4. , -5. ],
#        [-3. , -2. ],
#        [-2. , -2.8],
#        [-1. , -1.1],
#        [ 0. ,  0. ],
#        [ 1. ,  1.5],
#        [ 2. ,  2.8],
#        [ 3. ,  3.2],
#        [ 4. ,  4.1]])

# %%
# cov(X, Y) = (sum (x - mean(X)) * (y - mean(Y)) ) * 1/(n-1)

covariance = 
covariance
# Out:
# array([[7.5       , 8.225     ],
#        [8.225     , 9.39194444]])

# %% [markdown]
# **2. Calcualte Eigenvectors and Eigenvalues**

# %%
eigvals, eigvecs = 
eigvals, eigvecs
# Out:
# (array([ 0.16675194, 16.7251925 ]), array([[-0.74641095, -0.66548531],
#         [ 0.66548531, -0.74641095]]))

# %%
u = 
v =

# %% [markdown]
# **3. Select M (< Ds) Eigenvectors with highest Eigenvalues**

# %%
print(eigvals)
# Out:
# [ 0.16675194 16.7251925 ]

# %%
v
# Out:
# array([[-0.66548531],
#        [-0.74641095]])

# %%
u
# Out:
# array([[-0.74641095],
#        [ 0.66548531]])

# %% [markdown]
# **4. Project data points to these Eigenvectors**

# %%
X_transformed = 
X_transformed
# Out:
# array([[ 6.39399598],
#        [ 3.48927782],
#        [ 3.42092127],
#        [ 1.48653735],
#        [ 0.        ],
#        [-1.78510173],
#        [-3.42092127],
#        [-4.38497096],
#        [-5.72222612]])

# %%
X_centered = X - X.mean(axis=0)

# plt.quiver(0, 0,
#            2 * np.sqrt(eigvals[0]) * u[0], 2 * np.sqrt(eigvals[0]) * u[1],
#            color="#919191", angles='xy', scale_units='xy', scale=1,
#            zorder=2, width=0.011)
# plt.quiver(0, 0,
#            2 * np.sqrt(eigvals[1]) * v[0], 2 * np.sqrt(eigvals[1]) * v[1],
#            color="#FF8177", angles='xy', scale_units='xy', scale=1,
#            zorder=2, width=0.011)

plt.quiver(0, 0,
          2 * u[0],  2 * u[1],
           color="#919191", angles='xy', scale_units='xy', scale=1,
           zorder=2, width=0.011)
plt.quiver(0, 0,
           2 * v[0], 2 * v[1],
           color="#FF8177", angles='xy', scale_units='xy', scale=1,
           zorder=2, width=0.011)
plt.scatter(X_centered[:, 0], X_centered[:, 1], alpha=0.3)
# [...] Add axes

# Assure that ticks are displayed with a specific step
# plt.figure(figsize=(12, 12))
ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax.yaxis.set_major_locator(ticker.MultipleLocator(5))

# draw axes
plt.axhline(0, c='#d6d6d6', zorder=0)
plt.axvline(0, c='#d6d6d6', zorder=0)

plt.xlabel("x")
plt.ylabel("y")

# assure x and y axis have the same scale
plt.axis('equal')

plt.show()

# %% [markdown]
# **3. Select M (< Ds) Eigenvectors with highest Eigenvalues**

# %%
sort_index = eigvals.argsort()[::-1]   

eigvals_sorted = eigvals[sort_index]
eigvecs_sorted = eigvecs[:, sort_index]
eigvecs_sorted
# Out:
# array([[-0.66548531, -0.74641095],
#        [-0.74641095,  0.66548531]])

# %%
X_transformed = 
X_transformed
# Out:
# array([[ 6.45205016, -0.3935427 ],
#        [ 3.54733201,  0.85650227],
#        [ 3.47897546, -0.42229693],
#        [ 1.54459154, -0.03738286],
#        [ 0.05805418, -0.05175997],
#        [-1.72704755,  0.20005704],
#        [-3.36286709,  0.31877699],
#        [-4.32691678, -0.16143984],
#        [-5.66417194, -0.30891401]])

# %%
plt.scatter(X_transformed[:, 0], X_transformed[:, 1], alpha=0.3)
# [...] Add axes

# Assure that ticks are displayed with a specific step
# plt.figure(figsize=(12, 12))
ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax.yaxis.set_major_locator(ticker.MultipleLocator(5))

# draw axes
plt.axhline(0, c='#d6d6d6', zorder=0)
plt.axvline(0, c='#d6d6d6', zorder=0)

# assure x and y axis have the same scale
plt.axis('equal')

plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")

plt.show()

# %% [markdown]
# ![](https://rishi-advani.com/random-projections/examples/kpca/pc.gif)

# %% [markdown]
#  ![image.png](data:image/png;base64,...)
